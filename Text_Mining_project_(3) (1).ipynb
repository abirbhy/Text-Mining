# %% [markdown]
# # **Text Summarizer and Analyser**

# %% [markdown]
# ### **Goal : In this project we develop a Pyhton application that :**
#
#
# *   Reads a text Document(article , paragraph , tweet , ..)
# *   returns its category(sport , business..)
#
#
# *   detects its main topic
# *   summarized it automatically to produce most important and relevant sentences in order (2sentences or more )
#
#
# *   identifies the emotional tone in it positive or negative or neutral

# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split
import numpy as np
import numpy as np
import re
import nltk
from sklearn.datasets import load_files
nltk.download('stopwords')
import pickle
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # 1. Reading Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import shutil
shutil.copy('/content/drive/My Drive/bbc-fulltext.zip','/content/sample_data')
# Out:
# '/content/sample_data/bbc-fulltext.zip'

# %%
# !unzip  /content/sample_data/bbc-fulltext.zip -d /content/sample_data
# Out:
# Archive:  /content/sample_data/bbc-fulltext.zip
#    creating: /content/sample_data/bbc/
#    creating: /content/sample_data/bbc/business/
#   inflating: /content/sample_data/bbc/business/001.txt
#   inflating: /content/sample_data/bbc/business/002.txt
#   inflating: /content/sample_data/bbc/business/003.txt
#   inflating: /content/sample_data/bbc/business/004.txt
#   inflating: /content/sample_data/bbc/business/005.txt
#   inflating: /content/sample_data/bbc/business/006.txt
#   inflating: /content/sample_data/bbc/business/007.txt
#   inflating: /content/sample_data/bbc/business/008.txt
#   inflating: /content/sample_data/bbc/business/009.txt
#   inflating: /content/sample_data/bbc/business/010.txt
#   inflating: /content/sample_data/bbc/business/011.txt
#   inflating: /content/sample_data/bbc/business/012.txt
#   inflating: /content/sample_data/bbc/business/013.txt
#   inflating: /content/sample_data/bbc/business/014.txt
#   inflating: /content/sample_data/bbc/business/015.txt
#   inflating: /content/sample_data/bbc/business/016.txt
#   inflating: /content/sample_data/bbc/business/017.txt
#   inflating: /content/sample_data/bbc/business/018.txt
#   inflating: /content/sample_data/bbc/business/019.txt
#   inflating: /content/sample_data/bbc/business/020.txt
#   inflating: /content/sample_data/bbc/business/021.txt
#   inflating: /content/sample_data/bbc/business/022.txt
#   inflating: /content/sample_data/bbc/business/023.txt
#   inflating: /content/sample_data/bbc/business/024.txt
#   inflating: /content/sample_data/bbc/business/025.txt
#   inflating: /content/sample_data/bbc/business/026.txt
#   inflating: /content/sample_data/bbc/business/027.txt
#   inflating: /content/sample_data/bbc/business/028.txt
#   inflating: /content/sample_data/bbc/business/029.txt
#   inflating: /content/sample_data/bbc/business/030.txt
#   inflating: /content/sample_data/bbc/business/031.txt
#   inflating: /content/sample_data/bbc/business/032.txt
#   inflating: /content/sample_data/bbc/business/033.txt
#   inflating: /content/sample_data/bbc/business/034.txt
#   inflating: /content/sample_data/bbc/business/035.txt
#   inflating: /content/sample_data/bbc/business/036.txt
#   inflating: /content/sample_data/bbc/business/037.txt
#   inflating: /content/sample_data/bbc/business/038.txt
#   inflating: /content/sample_data/bbc/business/039.txt
#   inflating: /content/sample_data/bbc/business/040.txt
#   inflating: /content/sample_data/bbc/business/041.txt
#   inflating: /content/sample_data/bbc/business/042.txt
#   inflating: /content/sample_data/bbc/business/043.txt
#   inflating: /content/sample_data/bbc/business/044.txt
#   inflating: /content/sample_data/bbc/tech/393.txt
#   inflating: /content/sample_data/bbc/tech/394.txt
#   inflating: /content/sample_data/bbc/tech/395.txt
#   inflating: /content/sample_data/bbc/tech/396.txt
#   inflating: /content/sample_data/bbc/tech/397.txt
#   inflating: /content/sample_data/bbc/tech/398.txt
#   inflating: /content/sample_data/bbc/tech/399.txt
#   inflating: /content/sample_data/bbc/tech/400.txt
#   inflating: /content/sample_data/bbc/tech/401.txt

# %%
from sklearn.datasets import load_files
movie_data = load_files(r"/content/sample_data/bbc",encoding='unicode_escape')
X, y = movie_data.data, movie_data.target

# %%
print(X[0])
# Out:
# Tate & Lyle boss bags top award
#
# Tate & Lyle's chief executive has been named European Businessman of the Year by a leading business magazine.
#
# Iain Ferguson was awarded the title by US publication Forbes for returning one of the UK's "venerable" manufacturers to the country's top 100 companies. The sugar group had been absent from the FTSE 100 for seven years until Mr Ferguson helped it return to growth. Tate's shares have leapt 55% this year, boosted by firming sugar prices and sales of its artificial sweeteners.
#
# "After years of a sagging stock price and a seven-year hiatus from the FTSE 100, one of Britain's venerable manufacturers has returned to the vaunted index," Forbes said. Mr Ferguson took the helm at the company in 2003, after spending most of his career at consumer goods giant Unilever. Tate & Lyle, which was an original member of the historic FT-30 index in 1935, operates more than 41 factories and 20 more additional production facilities in 28 countries. Previous winners of the Forbes award include Royal Bank of Scotland chief executive Fred Goodwin and former Vodafone boss Chris Gent.

# %%
print(y)
print(y.shape)
# Out:
# [0 4 2 ... 1 1 3]
# (2225,)

# %% [markdown]
# # **Task 1 : Getting the category of the article**

# %% [markdown]
# ### **2.Text Preprocessing**

# %%
X1 = X
y1 = y

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
import re
documents = []

from nltk.stem import WordNetLemmatizer

stemmer = WordNetLemmatizer()

for sen in range(0, len(X1)):
    # Remove all the special characters
    document = re.sub(r'\W', ' ', str(X[sen]))
    
    # remove all single characters
    document = re.sub(r'\s+[a-zA-Z]\s+', ' ', document)
    
    # Remove single characters from the start
    document = re.sub(r'\^[a-zA-Z]\s+', ' ', document) 
    
    # Substituting multiple spaces with single space
    document = re.sub(r'\s+', ' ', document, flags=re.I)
    
    # Removing prefixed 'b'
    document = re.sub(r'^b\s+', '', document)
    
    # Converting to Lowercase
    document = document.lower()
    
    # Lemmatization
    document = document.split()

    document = [stemmer.lemmatize(word) for word in document]
    document = ' '.join(document)
    
    documents.append(document)

# %%
print(documents[0])
# Out:
# tate lyle bos bag top award tate lyle chief executive ha been named european businessman of the year by leading business magazine iain ferguson wa awarded the title by u publication forbes for returning one of the uk venerable manufacturer to the country top 100 company the sugar group had been absent from the ftse 100 for seven year until mr ferguson helped it return to growth tate share have leapt 55 this year boosted by firming sugar price and sale of it artificial sweetener after year of sagging stock price and seven year hiatus from the ftse 100 one of britain venerable manufacturer ha returned to the vaunted index forbes said mr ferguson took the helm at the company in 2003 after spending most of his career at consumer good giant unilever tate lyle which wa an original member of the historic ft 30 index in 1935 operates more than 41 factory and 20 more additional production facility in 28 country previous winner of the forbes award include royal bank of scotland chief executive fred goodwin and former vodafone bos chris gent

# %% [markdown]
# ### **3.Sequence Creation**

# %% [markdown]
# ## **Bag Of Words**

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(max_features=1500, min_df=5, max_df=0.7, stop_words=stopwords.words('english'))
X1 = vectorizer.fit_transform(documents).toarray()

# %% [markdown]
# ## **Tf-Idf:**

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidfconverter = TfidfTransformer()
X1 = tfidfconverter.fit_transform(X1).toarray()

# %% [markdown]
# ## **4.Splitting the Dataset**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=0)

# %% [markdown]
# ## **5.Training the model**

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=1000, random_state=0)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([0, 1, 4, 1, 1, 4, 2, 4, 1, 4, 3, 3, 2, 0, 1, 0, 0, 2, 3, 0, 4, 0,
#        0, 3, 4, 3, 4, 2, 3, 0, 1, 3, 4, 0, 4, 2, 4, 1, 1, 0, 3, 4, 4, 4,
#        0, 4, 3, 0, 2, 0, 4, 1, 2, 3, 1, 2, 3, 0, 3, 0, 1, 2, 4, 1, 2, 2,
#        0, 0, 0, 1, 4, 1, 0, 4, 3, 0, 1, 0, 4, 1, 0, 4, 2, 2, 0, 3, 0, 3,
#        2, 3, 0, 3, 0, 1, 4, 4, 2, 0, 1, 4, 0, 2, 4, 2, 3, 1, 1, 0, 3, 2,
#        0, 3, 3, 0, 0, 0, 1, 3, 3, 1, 1, 3, 3, 1, 3, 1, 3, 0, 3, 3, 4, 2,
#        4, 1, 2, 0, 3, 2, 1, 1, 1, 1, 1, 3, 4, 3, 4, 3, 4, 4, 3, 1, 4, 0,
#        2, 1, 0, 3, 4, 0, 3, 1, 2, 3, 3, 1, 0, 2, 1, 2, 3, 3, 4, 1, 2, 4,
#        1, 3, 2, 4, 2, 3, 1, 1, 1, 1, 3, 4, 3, 1, 0, 4, 2, 0, 4, 1, 4, 3,
#        3, 4, 4, 0, 1, 2, 0, 0, 1, 0, 4, 3, 0, 4, 3, 0, 1, 3, 0, 0, 3, 3,
#        1, 0, 3, 3, 0, 2, 2, 2, 3, 3, 1, 2, 4, 0, 0, 2, 1, 2, 0, 4, 0, 1,
#        3, 1, 1, 4, 0, 3, 4, 1, 4, 1, 0, 4, 2, 1, 3, 4, 1, 0, 3, 0, 3, 1,
#        3, 2, 4, 3, 3, 4, 3, 2, 4, 3, 0, 3, 2, 3, 2, 0, 3, 4, 3, 1, 2, 3,
#        0, 4, 0, 2, 3, 1, 0, 2, 4, 1, 2, 3, 0, 3, 0, 4, 2, 0, 0, 3, 0, 3,
#        2, 3, 4, 3, 2, 2, 2, 4, 2, 4, 0, 2, 2, 3, 1, 4, 3, 2, 3, 2, 1, 0,
#        0, 1, 0, 2, 0, 3, 3, 2, 2, 1, 0, 0, 1, 4, 2, 0, 4, 4, 3, 3, 0, 4,
#        4, 3, 4, 1, 3, 4, 2, 1, 1, 0, 0, 1, 2, 3, 3, 4, 2, 4, 1, 0, 2, 3,
#        2, 2, 3, 3, 0, 0, 4, 0, 0, 2, 0, 0, 1, 3, 0, 2, 3, 2, 3, 1, 0, 3,
#        0, 4, 2, 0, 0, 4, 2, 2, 3, 4, 1, 1, 4, 1, 0, 0, 0, 3, 2, 3, 3, 1,
#        0, 2, 3, 0, 3, 3, 2, 0, 2, 3, 1, 3, 4, 0, 2, 3, 1, 0, 4, 2, 3, 1,
#        0, 4, 4, 0, 4])

# %%
print(y_test)
# Out:
# [0 1 4 1 1 4 2 4 1 4 3 3 2 0 1 0 0 2 3 0 4 0 0 3 4 3 4 2 3 0 1 3 4 0 4 2 0
#  1 1 0 3 4 4 4 0 4 3 1 2 2 4 1 2 3 1 0 3 0 3 0 1 2 4 1 2 2 0 0 0 1 4 1 0 4
#  3 0 1 0 4 1 0 4 2 0 0 2 0 3 2 3 0 3 2 1 4 4 2 0 1 4 0 2 4 2 3 1 1 0 3 2 0
#  3 3 0 0 0 4 3 3 1 1 3 3 1 3 1 3 0 3 3 4 2 0 1 2 0 3 2 1 1 1 1 1 3 4 3 4 3
#  4 4 3 1 4 0 2 1 0 3 4 0 3 1 2 3 3 1 0 2 1 2 3 3 4 1 2 4 1 3 2 4 2 3 1 1 1
#  1 3 4 3 1 0 4 2 0 4 1 4 3 3 4 4 0 1 2 0 0 1 0 4 3 0 4 3 0 1 3 0 0 3 3 1 0
#  3 3 0 2 1 2 3 3 1 2 4 0 0 2 1 2 0 4 2 1 3 1 1 1 0 3 0 1 4 1 0 4 2 1 3 4 1
#  0 3 0 3 1 3 2 4 3 3 4 3 2 4 3 0 3 2 3 2 0 3 4 3 1 2 3 0 4 0 2 3 1 0 2 4 1
#  2 3 0 3 0 4 2 0 0 3 0 1 2 3 4 3 2 2 2 4 2 4 0 2 2 3 1 4 3 2 3 2 1 0 0 1 0
#  2 0 3 3 2 2 1 0 0 1 4 2 0 4 4 3 3 0 4 4 3 4 1 3 4 2 1 1 0 0 1 2 3 3 4 2 4
#  1 0 2 3 2 2 3 3 0 0 4 0 0 2 0 0 1 3 0 2 3 2 3 1 0 3 0 4 2 0 0 4 2 2 3 4 1
#  1 4 1 0 0 0 4 2 3 3 1 1 2 3 0 3 3 2 0 2 3 1 3 4 0 2 3 1 0 4 2 3 1 0 4 4 0
#  4]

# %% [markdown]
# ## **6.Evaluation**

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[ 97   0   2   0   3]
#  [  2  79   1   1   1]
#  [  3   0  74   1   0]
#  [  0   0   0 103   0]
#  [  0   1   0   1  76]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       102
#            1       0.99      0.94      0.96        84
#            2       0.96      0.95      0.95        78
#            3       0.97      1.00      0.99       103
#            4       0.95      0.97      0.96        78
#
#     accuracy                           0.96       445
#    macro avg       0.96      0.96      0.96       445
# weighted avg       0.96      0.96      0.96       445
#
# 0.9640449438202248

# %% [markdown]
# # **Task 2 :Detecting the topic of an article**

# %%
X2 = X
y2 = y

# %% [markdown]
# ## **create vocabulary of all the words in our data**

# %%
print(X2[:2])
# Out:
# ['Tate & Lyle boss bags top award\n\nTate & Lyle\'s chief executive has been named European Businessman of the Year by a leading business magazine.\n\nIain Ferguson was awarded the title by US publication Forbes for returning one of the UK\'s "venerable" manufacturers to the country\'s top 100 companies. The sugar group had been absent from the FTSE 100 for seven years until Mr Ferguson helped it return to growth. Tate\'s shares have leapt 55% this year, boosted by firming sugar prices and sales of its artificial sweeteners.\n\n"After years of a sagging stock price and a seven-year hiatus from the FTSE 100, one of Britain\'s venerable manufacturers has returned to the vaunted index," Forbes said. Mr Ferguson took the helm at the company in 2003, after spending most of his career at consumer goods giant Unilever. Tate & Lyle, which was an original member of the historic FT-30 index in 1935, operates more than 41 factories and 20 more additional production facilities in 28 countries. Previous winners of the Forbes award include Royal Bank of Scotland chief executive Fred Goodwin and former Vodafone boss Chris Gent.\n', "Halo 2 sells five million copies\n\nMicrosoft is celebrating bumper sales of its Xbox sci-fi shooter, Halo 2.\n\nThe game has sold more than five million copies worldwide since it went on sale in mid-November, the company said. Halo 2 has proved popular online, with gamers notching up a record 28 million hours playing the game on Xbox Live. According to Microsoft, nine out of 10 Xbox Live members have played the game for an average of 91 minutes per session.\n\nThe sequel to the best-selling Need for Speed: Underground has inched ahead of the competition to take the top slot in the official UK games charts. The racing game moved up one spot to first place, nudging GTA: San Andreas down to second place. Halo 2 dropped one place to five, while Half-Life 2 fell to number nine. Last week's new releases, GoldenEye: Rogue Agent and Killzone, both failed to make it into the top 10, debuting at number 11 and 12 respectively.\n\nRecord numbers of Warcraft fans are settling in the games online world. On the opening day of the World of Warcraft massive multi-player online game more than 200,000 players signed up to play. On the evening of the first day more than 100,000 players were in the world, forcing Blizzard to add another 34 servers to cope with the influx. The online game turns the stand alone Warcraft games into a persistent world that players can inhabit not just visit\n\nEurope's gamers could be waiting until January to hear when they can get their mitts on Nintendo's handheld device, Nintendo DS, says gamesindustry.biz. David Yarnton, Nintendo UK general manager, told a press conference to look out for details in the New Year. Its US launch was on Sunday and it goes on sale in Japan on 2 December. Nintendo has a 95% share of the handheld gaming market and said it expected to sell around five million of the DS by March 2005.\n"]

# %%
import numpy as np
myarray = np.asarray(X2)

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vect = CountVectorizer(max_df=0.8, min_df=2, stop_words='english')
doc_term_matrix = count_vect.fit_transform(myarray)
doc_term_matrix
# Out:
# <2225x17472 sparse matrix of type '<class 'numpy.int64'>'
# 	with 308605 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## **Use the LDA**

# %%
from sklearn.decomposition import LatentDirichletAllocation

LDA = LatentDirichletAllocation(n_components=5, random_state=42)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=5, n_jobs=None,
#                           perp_tol=0.1, random_state=42, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
import random
#fetches 10 words from our vocabulary
for i in range(10):
    random_id = random.randint(0,len(count_vect.get_feature_names()))
    print(count_vect.get_feature_names()[random_id])
# Out:
# kazakhstan
# tried
# attend
# dickens
# werner
# benefits
# realize
# semitism
# unequivocal
# hefty

# %%
first_topic = LDA.components_[0]
first_topic
# Out:
# array([  3.45603771, 170.88101497,  41.1805826 , ...,   0.21961147,
#          0.20000011,   0.21125222])

# %%
top_topic_words = first_topic.argsort()[-10:]
top_topic_words
# Out:
# array([ 6928, 15662, 16292, 10392, 17386, 10773,  2177, 10601,  6422,
#        11614])

# %%
for i in top_topic_words:
    print(count_vect.get_feature_names()[i])
# Out:
# games
# technology
# tv
# mobile
# year
# new
# best
# music
# film
# people

# %%
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([count_vect.get_feature_names()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['games', 'technology', 'tv', 'mobile', 'year', 'new', 'best', 'music', 'film', 'people']
#
#
# Top 10 words for topic #1:
# ['new', 'brown', 'minister', 'blair', 'party', 'election', 'people', 'labour', 'government', 'mr']
#
#
# Top 10 words for topic #2:
# ['000', 'economic', 'world', '2004', 'economy', 'new', 'sales', 'growth', 'market', 'year']
#
#
# Top 10 words for topic #3:
# ['players', 'team', 'wales', 'play', 'world', 'win', 'time', 'england', 'year', 'game']
#
#
# Top 10 words for topic #4:
# ['legal', 'yukos', 'people', 'court', 'security', 'new', 'software', 'firm', 'company', 'mr']

# %%
topic_values = LDA.transform(doc_term_matrix)
topic_values.shape
# Out:
# (2225, 5)

# %% [markdown]
# # **Task3 ; Article summarization:**

# %%
X3 = X
y3 = y

# %%
from collections import Counter 
from string import punctuation
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS as stop_words
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_extraction.stop_words module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_extraction.text. Anything that cannot be imported from sklearn.feature_extraction.text is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
def tokenizer(s):
    tokens = []
    for word in s.split(' '):
        tokens.append(word.strip().lower())
    return tokens

def sent_tokenizer(l):
    sents = []
    for sent in l :
        for senten in sent.split('.'):
            sents.append(senten.strip())
    return sents

# %% [markdown]
# ## **1.Preprocessing**

# %%
TAG_RE = re.compile(r'<[^>]+>')

def remove_tags(text):
    return TAG_RE.sub('', text)

# %%
def preprocess_text(sen):
    # Removing html tags
    sentence = remove_tags(sen)

    # Remove punctuations and numbers
    sentence = re.sub('[^a-zA-Z]', ' ', sentence)

    # Single character removal
    sentence = re.sub(r"\s+[a-zA-Z]\s+", ' ', sentence)

    # Removing multiple spaces
    sentence = re.sub(r'\s+', ' ', sentence)

    return sentence

# %%
print(sentence_list[:5])
# Out:
# [["Tate & Lyle boss bags top award\n\nTate & Lyle's chief executive has been named European Businessman of the Year by a leading business magazine.", 'Iain Ferguson was awarded the title by US publication Forbes for returning one of the UK\'s "venerable" manufacturers to the country\'s top 100 companies.', 'The sugar group had been absent from the FTSE 100 for seven years until Mr Ferguson helped it return to growth.', "Tate's shares have leapt 55% this year, boosted by firming sugar prices and sales of its artificial sweeteners.", '"After years of a sagging stock price and a seven-year hiatus from the FTSE 100, one of Britain\'s venerable manufacturers has returned to the vaunted index," Forbes said.', 'Mr Ferguson took the helm at the company in 2003, after spending most of his career at consumer goods giant Unilever.', 'Tate & Lyle, which was an original member of the historic FT-30 index in 1935, operates more than 41 factories and 20 more additional production facilities in 28 countries.', 'Previous winners of the Forbes award include Royal Bank of Scotland chief executive Fred Goodwin and former Vodafone boss Chris Gent.'], ['Halo 2 sells five million copies\n\nMicrosoft is celebrating bumper sales of its Xbox sci-fi shooter, Halo 2.', 'The game has sold more than five million copies worldwide since it went on sale in mid-November, the company said.', 'Halo 2 has proved popular online, with gamers notching up a record 28 million hours playing the game on Xbox Live.', 'According to Microsoft, nine out of 10 Xbox Live members have played the game for an average of 91 minutes per session.', 'The sequel to the best-selling Need for Speed: Underground has inched ahead of the competition to take the top slot in the official UK games charts.', 'The racing game moved up one spot to first place, nudging GTA: San Andreas down to second place.', 'Halo 2 dropped one place to five, while Half-Life 2 fell to number nine.', "Last week's new releases, GoldenEye: Rogue Agent and Killzone, both failed to make it into the top 10, debuting at number 11 and 12 respectively.", 'Record numbers of Warcraft fans are settling in the games online world.', 'On the opening day of the World of Warcraft massive multi-player online game more than 200,000 players signed up to play.', 'On the evening of the first day more than 100,000 players were in the world, forcing Blizzard to add another 34 servers to cope with the influx.', "The online game turns the stand alone Warcraft games into a persistent world that players can inhabit not just visit\n\nEurope's gamers could be waiting until January to hear when they can get their mitts on Nintendo's handheld device, Nintendo DS, says gamesindustry.biz.", 'David Yarnton, Nintendo UK general manager, told a press conference to look out for details in the New Year.', 'Its US launch was on Sunday and it goes on sale in Japan on 2 December.', 'Nintendo has a 95% share of the handheld gaming market and said it expected to sell around five million of the DS by March 2005.'], ['MSPs hear renewed climate warning\n\nClimate change could be completely out of control within several decades, the Scottish Environment Protection Agency is warning a committee of MSPs.', "Experts are giving evidence on the subject to the Scottish Parliament's environment committee.", 'Officials believe nuclear energy and wind farms may be better options than trying to tackle global warming.', 'Solutions suggested by conservationists include reducing internal UK air travel and boosting electric trains.', "The evidence is part of the committee's inquiry into the impact of climate change in Scotland.", 'Sepa is attempting to curb global warming gases, as pollution from transport emissions increases.', 'Ecologists are warning MSPs that Scotland may have to accept "significant intrusion" from wind farms.', 'It is likely also that nuclear power will be needed for possibly several decades.', 'Sepa predict that the two methods will remain as energy  ...

# %%
sentences = []

for sen in sentences_list:
    sentences.append(preprocess_text(sen))

# %%
text = " ".join(sentences)
tokens = tokenizer(text)


print(tokens[:2])
# Out:
# ['tate', 'lyle']

# %%
sents = sent_tokenizer(sentences)
print(sents[0])
# Out:
# Tate Lyle boss bags top award Tate Lyle chief executive has been named European Businessman of the Year by leading business magazine

# %% [markdown]
# ## **2.Find Weighted Frequency of Occurrence**

# %%
def count_words(tokens):
    word_counts = {}
    for token in tokens:
        if token not in stop_words and token not in punctuation:
            if token not in word_counts.keys():
                word_counts[token] = 1
            else:
                word_counts[token] += 1
    return word_counts

word_counts = count_words(tokens)
word_counts
# Out:
# {'tate': 21,
#  'lyle': 3,
#  'boss': 161,
#  'bags': 6,
#  'award': 291,
#  'chief': 460,
#  'executive': 314,
#  'named': 130,
#  'european': 525,
#  'businessman': 6,
#  'year': 2310,
#  'leading': 151,
#  'business': 392,
#  'magazine': 100,
#  'iain': 4,
#  'ferguson': 90,
#  'awarded': 36,
#  'title': 217,
#  'publication': 21,
#  'forbes': 4,
#  'returning': 36,
#  'uk': 1115,
#  'venerable': 3,
#  'manufacturers': 47,
#  'country': 528,
#  'companies': 428,
#  'sugar': 7,
#  'group': 498,
#  'absent': 10,
#  'ftse': 11,
#  'seven': 145,
#  'years': 1003,
#  'mr': 3005,
#  'helped': 140,
#  'return': 258,
#  'growth': 467,
#  'shares': 276,
#  'leapt': 4,
#  'boosted': 36,
#  'firming': 1,
#  'prices': 289,
#  'sales': 494,
#  'artificial': 13,
#  'sweeteners': 7,
#  'sagging': 1,
#  'stock': 181,
#  'price': 216,
#  'hiatus': 3,
#  'britain': 450,
#  'returned': 61,
#  'vaunted': 2,
#  'index': 72,
#  'said': 7255,
#  'took': 366,
#  'helm': 9,
#  'company': 686,
#  'spending': 282,
#  'career': 187,
#  'consumer': 218,
#  'goods': 58,
#  'giant': 158,
#  'unilever': 13,
#  'original': 128,
#  'member': 122,
#  'historic': 21,
#  'ft': 18,
#  'operates': 29,
#  'factories': 17,
#  'additional': 37,
#  'production': 196,
#  'facilities': 27,
#  'countries': 312,
#  'previous': 185,
#  'winners': 102,
#  'include': 237,
#  'royal': 62,
#  'bank': 380,
#  'scotland': 256,
#  'fred': 6,
#  'goodwin': 1,
#  'vodafone': 47,
#  'chris': 67,
#  'gent': 1,
#  'halo': 46,
#  'sells': 12,
#  'million': 579,
#  'copies': 83,
#  'microsoft': 277,
#  'celebrating': 11,
#  'bumper': 6,
#  'xbox': 81,
#  'sci': 11,
#  'fi': 68,
#  'shooter': 14,
#  'game': 871,
#  'sold': 232,
#  'worldwide': 77,
#  'went': 272,
#  'sale': 244,
#  'mid': 56,
#  'november': 213,
#  'proved': 76,
#  'popular': 174,
#  'online': 345,
#  'gamers': 87,
#  'notching': 2,
#  'record': 425,
#  'hours': 142,
#  'playing': 295,
#  'live': 191,
#  'according': 422,
#  'members': 207,
#  'played': 280,
#  'average': 134,
#  'minutes': 223,
#  'session': 45,
#  'sequel': 45,
#  'best': 974,
#  'selling': 120,
#  'need': 419,
#  'speed': 135,
#  'underground': 23,
#  'inched': 4,
#  'ahead': 267,
#  'competition': 188,
#  'slot': 20,
#  'official': 144,
#  'games': 622,
#  'charts': 59,
#  'racing': 29,
#  'moved': 106,
#  'spot': 86,
#  'place': 403,
#  'nudging': 2,
#  'gta': 12,
#  'san': 70,
#  'andreas': 23,
#  'second': 605,
#  'dropped': 102,
#  'half': 474,
#  'life': 380,
#  'fell': 155,
#  'number': 760,
#  'week': 594,
#  'new': 1978,
#  'releases': 23,
#  'goldeneye': 6,
#  'rogue': 14,
#  'agent': 42,
#  'killzone': 1,
#  'failed': 177,
#  'make': 945,
#  'debuting': 2,
#  'respectively': 24,
#  'numbers': 133,
#  'warcraft': 12,
#  'fans': 208,
#  'settling': 5,
#  'world': 1201,
#  'opening': 147,
#  'day': 466,
#  'massive': 89,
#  'multi': 43,
#  'player': 309,
#  'players': 524,
#  'signed': 118,
#  'play': 572,
#  'evening': 60,
#  'forcing': 14,
#  'blizzard': 3,
#  'add': 96,
#  'servers': 38,
#  'cope': 43,
#  'influx': 2,
#  'turns': 33,
#  'stand': 143,
#  'persistent': 15,
#  'inhabit': 1,
#  'just': 957,
#  'visit': 65,
#  'europe': 412,
#  'waiting': 76,
#  'january': 309,
#  'hear': 50,
#  'mitts': 1,
#  'nintendo': 90,
#  'handheld': 60,
#  'device': 113,
#  'ds': 59,
#  'says': 687,
#  'gamesindustry': 2,
#  'biz': 6,
#  'david': 257,
#  'yarnton': 3,
#  'general': 366,
#  'manager': 220,
#  'told': 911,
#  'press': 134,
#  'conference': 159,
#  'look': 298,
#  'details': 112,
#  'launch': 158,
#  'sunday': 252,
#  'goes': 94,
#  'japan': 218,
#  'december': 303,
#  'share': 236,
#  'gaming': 170,
#  'market': 702,
#  'expected': 507,
#  'sell': 134,
#  'march': 230,
#  'msps': 9,
#  'renewed': 21,
#  'climate': 37,
#  'warning': 85,
#  'change': 261,
#  'completely': 68,
#  'control': 274,
#  'decades': 30,
#  'scottish': 138,
#  'environment': 74,
#  'protection': 105,
#  'agency': 133,
#  'committee': 184,
#  'experts': 93,
#  'giving': 102,
#  'evidence': 181,
#  'subject': 79,
#  'parliament': 158,
#  'officials': 130,
#  'believe': 272,
#  'nuclear': 51,
#  'energy': 127,
#  'wind': 14,
#  'farms': 10,
#  'better': 356,
#  'options': 46,
#  'trying': 190,
#  'tackle': 85,
#  'global': 198,
#  'warming': 7,
#  'solutions': 25,
#  'suggested': 108,
#  'conservationists': 1,
#  'reducing': 40,
#  'internal': 29,
#  'air': 119,
#  'travel': 79,
#  'boosting': 25,
#  'electric': 11,
#  'trains': 12,
#  'inquiry': 82,
#  'impact': 132,
#  'sepa': 5,
#  'attempting': 23,
#  'curb': 9,
#  'gases': 2,
#  'pollution': 5,
#  'transport': 72,
#  'emissions': 10,
#  'increases': 60,
#  'ecologists': 1,
#  'accept': 68,
#  'significant': 104,
#  'intrusion': 3,
#  'likely': 328,
#  'power': 249,
#  'needed': 218,
#  'possibly': 28,
#  'predict': 33,
#  'methods': 18,
#  'remain': 148,
#  'sources': 48,
#  'studying': 23,
#  'seas': 4,
#  'west': 143,
#  'coast': 21,
#  'forecast': 70,
#  'devastating': 9,
#  'weather': 41,
#  'type': 55,
#  'caused': 68,
#  'havoc': 1,
#  'month': 419,
#  'predicted': 97,
#  'damaging': 34,
#  'storms': 5,
#  'frequent': 4,
#  'researchers': 45,
#  'university': 134,
#  'highlands': 6,
#  'islands': 19,
#  'southampton': 42,
#  'looking': 263,
#  'wave': 27,
#  'heights': 7,
#  'atlantic': 19,
#  'project': 175,
#  'conducted': 42,
#  'jointly': 15,
#  'environmental': 47,
#  'research': 292,
#  'institute': 57,
#  'thurso': 2,
#  'uhi': 1,
#  'millennium': 24,
#  'network': 222,
#  'oceanography': 1,
#  'centre': 199,
#  'scientists': 19,
#  'carried': 61,
#  'series': 255,
#  'studies': 29,
#  'including': 407,
#  'use': 585,
#  'satellites': 2,
#  'assess': 29,
#  'hebrides': 1,
#  'pavey': 9,
#  'focuses': 8,
#  'indoor': 89,
#  'success': 196,
#  'jo': 7,
#  'miss': 62,
#  'view': 129,
#  'great': 385,
#  'edinburgh': 78,
#  'international': 405,
#  'cross': 117,
#  'focus': 123,
#  'preparing': 33,
#  'championships': 84,
#  'old': 478,
#  'hayley': 7,
#  'yelling': 17,
#  'justyna': 1,
#  'bak': 1,
#  'prefers': 4,
#  'race': 178,
#  'track': 114,
#  'winning': 246,
#  'bronze': 17,
#  'm': 686,
#  'wary': 9,
#  'injuries': 45,
#  'concentrate': 15,
#  'season': 272,
#  'don': 444,
#  'run': 316,
#  'hills': 8,
#  'training': 118,
#  'came': 360,
#  'fifth': 71,
#  'athens': 101,
#  'olympics': 66,
#  'british': 542,
#  'team': 401,
#  'win': 613,
#  'silver': 34,
#  'medal': 51,
#  'heringsdorf': 1,
#  'start': 371,
#  'boston': 29,
#  'stuttgart': 4,
#  'end': 517,
#  'tories': 243,
#  'reject': 23,
#  'rethink': 13,
#  'axed': 12,
#  'mp': 174,
#  'sacked': 25,
#  'howard': 364,
#  'flight': 49,
#  'local': 268,
#  'conservative': 142,
#  'association': 150,
#  'insisted': 116,
#  'candidate': 43,
#  'election': 662,
#  'russell': 17,
#  'tanguay': 3,
#  'arundel': 2,
#  'south': 259,
#  'downs': 4,
#  'ineligible': 3,
#  'seeking': 62,
#  'substitute': 14,
#  'news': 518,
#  'comes': 184,
#  'despite': 334,
#  'allies': 27,
#  'saying': 321,
#  'support': 273,
#  'hold': 203,
#  'meeting': 242,
#  'discuss': 59,
#  'fate': 13,
#  'landed': 19,
#  'trouble': 69,
#  'remarks': 27,
#  'tory': 273,
#  'tax': 431,
#  'plans': 486,
#  'quit': 65,
#  'deputy': 69,
#  'chairman': 230,
#  'apparently': 22,
#  'suggesting': 30,
#  'planned': 92,
#  'extra': 134,
#  'cuts': 128,
#  'wants': 180,
#  'continue': 219,
#  'headquarters': 27,
#  'longer': 119,
#  'approved': 39,
#  'backed': 94,
#  'tuesday': 219,
#  'party': 630,
#  'process': 128,
#  'selecting': 7,
#  'similar': 153,
#  'comments': 126,
#  'friday': 202,
#  'dissent': 4,
#  'continues': 70,
#  'councillors': 8,
#  'met': 108,
#  'afternoon': 23,
#  'did': 538,
#  'comment': 90,
#  'left': 298,
#  'unless': 66,
#  'instructs': 1,
#  'extraordinary': 23,
#  'egm': 2,
#  'consulting': 13,
#  'lawyers': 54,
#  'bbc': 778,
#  'selected': 33,
#  'like': 879,
#  'dispose': 2,
#  'supporters': 87,
#  'say': 582,
#  'signatures': 3,
#  'trigger': 14,
#  'rules': 184,
#  'leader': 288,
#  'argues': 34,
#  'ensuring': 35,
#  'honesty': 8,
#  'thing': 201,
#  'private': 131,
#  'public': 557,
#  'labour': 804,
#  'campaign': 332,
#  'coordinator': 9,
#  'alan': 114,
#  'milburn': 69,
#  'turmoil': 2,
#  'exposed': 18,
#  'hidden': 30,
#  'claiming': 68,
#  'senior': 148,
#  'obsessively': 2,
#  'committed': 64,
#  'cutting': 72,
#  'liberal': 175,
#  'democrat': 72,
#  'matthew': 33,
#  'taylor': 91,
#  'whilst': 40,
#  'disagree': 7,
#  'views': 61,
#  'sack': 13,
#  'somebody': 27,
#  'telling': 45,
#  'truth': 36,
#  'emerged': 51,
#  'suspended': 80,
#  'slough': 6,
#  'constituency': 35,
#  'refusing': 13,
#  'deselect': 2,
#  'adrian': 12,
#  'hilton': 6,
#  'abandoned': 18,
#  'signing': 47,
#  'maastricht': 1,
#  'treaty': 18,
#  'john': 261,
#  'major': 268,
#  'government': 1160,
#  'act': 211,
#  'treason': 2,
#  'catholic': 22,
#  'herald': 11,
#  'highlighted': 38,
#  'articles': 17,
#  'wrote': 62,
#  'role': 283,
#  'catholicism': 1,
#  'union': 201,
#  'chosen': 61,
#  'fight': 136,
#  'seat': 46,
#  'robert': 118,
#  'oulds': 1,
#  'pictured': 3,
#  'range': 152,
#  'guns': 11,
#  'hunting': 81,
#  'knife': 17,
#  'placed': 42,
#  'status': 39,
#  'spokesman': 356,
#  'considering': 57,
#  'taking': 292,
#  'legal': 286,
#  'action': 331,
#  'deposal': 1,
#  'learned': 18,
#  'final': 379,
#  'decision': 339,
#  'website': 242,
#  'monday': 207,
#  'people': 2045,
#  'central': 112,
#  'office': 348,
#  'behaving': 8,
#  'little': 279,
#  'dictators': 2,
#  'seemingly': 9,
#  'ordinary': 36,
#  'treated': 31,
#  'contempt': 9,
#  'try': 255,
#  'contact': 45,
#  'lib': 180,
#  'dems': 102,
#  'poll': 119,
#  'set': 762,
#  'results': 148,
#  'council': 208,
#  'polls': 25,
#  'frontbenchers': 1,
#  'ed': 17,
#  'davey': 7,
#  'speaking': 122,
#  'launched': 152,
#  'elections': 94,
#  'held': 259,
#  'english': 108,
#  'areas': 131,
#  'flagship': 10,
#  'pledge': 30,
#  'replace': 70,
#  'income': 105,
#  'pay': 291,
#  'sums': 20,
#  'coming': 210,
#  'going': 632,
#  'votes': 47,
#  'seats': 53,
#  'think': 596,
#  'charles': 170,
#  'kennedy': 135,
#  'couldn': 38,
#  'stronger': 56,
#  'endorsement': 1,
#  'attacks': 157,
#  'later': 293,
#  'budget': 266,
#  'michael': 287,
#  'dismissed': 47,
#  'gordon': 148,
#  'brown': 471,
#  'vote': 199,
#  'simple': 75,
#  'fact': 172,
#  'taxes': 137,
#  'plug': 9,
#  'financial': 264,
#  'black': 153,
#  'hole': 25,
#  'chancellor': 270,
#  'hid': 3,
#  'rises': 61,
#  'hard': 290,
#  'working': 269,
#  'families': 81,
#  'faltering': 8,
#  'package': 49,
#  'measures': 102,
#  'added': 733,
#  'good': 646,
#  'interests': 65,
#  'mockingly': 1,
#  'welcoming': 4,
#  'accuse': 10,
#  'hand': 122,
#  'away': 314,
#  'urged': 73,
#  'admit': 14,
#  'responsible': 74,
#  'dragging': 6,
#  'millions': 112,
#  'net': 454,
#  'stamp': 24,
#  'duty': 75,
#  'inheritance': 9,
#  'hide': 29,
#  'crippling': 2,
#  'inevitable': 12,
#  'wins': 99,
#  'accused': 149,
#  'running': 201,
#  'problems': 232,
#  'faced': 70,
#  'answer': 91,
#  'spend': 123,
#  'waste': 53,
#  'liked': 15,
#  'rattle': 2,
#  'magical': 5,
#  'balances': 4,
#  'conjured': 1,
#  'bid': 212,
#  'convince': 7,
#  'nation': 68,
#  'finances': 39,
#  'dodgy': 8,
#  'brought': 126,
#  'dossier': 12,
#  'publishing': 17,
#  'based': 420,
#  'propose': 8,
#  'borrow': 13,
#  'billion': 88,
#  'prudence': 3,
#  'forecasts': 56,
#  'surpluses': 3,
#  'prime': 328,
#  'minister': 561,
#  'weapons': 31,
#  'mass': 53,
#  'destruction': 31,
#  'rebate': 23,
#  'pensioners': 32,
#  'offering': 95,
#  'police': 262,
#  'streets': 40,
#  'hospitals': 34,
#  'cleaner': 10,
#  'parents': 105,
#  'teachers': 29,
#  'discipline': 31,
#  'skills': 61,
#  'wanted': 195,
#  'schools': 119,
#  'face': 269,
#  'clear': 232,
#  'choice': 170,
#  'higher': 186,
#  'lower': 121,
#  'value': 143,
#  'money': 440,
#  'conservatives': 112,
#  'battleground': 4,
#  'bring': 136,
#  'concluded': 27,
#  'loud': 5,
#  'cheering': 3,
#  'blu': 32,
#  'ray': 113,
#  'dvd': 167,
#  'format': 68,
#  'generation': 128,
#  'rival': 107,
#  'backers': 9,
#  'firms': 396,
#  'sony': 190,
#  'competing': 52,
#  'toshiba': 29,
#  'nec': 13,
#  'hd': 55,
#  'future': 373,
#  'films': 258,
#  'thursday': 172,
#  'giants': 25,
#  'electronic': 71,
#  'arts': 49,
#  'vivendi': 18,
#  'dvds': 64,
#  'high': 559,
#  'definition': 99,
#  'video': 363,
#  'sound': 99,
#  'offers': 91,
#  'incredible': 30,
#  'quality': 123,
#  'pictures': 82,
#  'hollywood': 115,
#  'studios': 69,
#  'publishers': 15,
#  'extremely': 56,
#  'keen': 105,
#  'exploit': 21,
#  'separate': 89,
#  'electronics': 83,
#  'las': 31,
#  'vegas': 30,
#  'announced': 252,
#  'technology': 561,
#  'standard': 132,
#  'images': 112,
#  'greater': 82,
#  'storage': 63,
#  'richard': 95,
#  'doherty': 24,
#  'panasonic': 5,
#  'laboratories': 9,
#  'pioneers': 12,
#  'utilising': 4,
#  'blue': 53,
#  'laser': 31,
#  'optical': 4,
#  'disc': 27,
#  'times': 305,
#  'today': 209,
#  'able': 313,
#  'store': 76,
#  'gb': 58,
#  'data': 326,
#  'making': 332,
#  'sure': 162,
#  'discs': 15,
#  'satisfy': 9,
#  'needs': 152,
#  'ability': 100,
#  'smaller': 70,
#  'fit': 88,
#  'camcorders': 4,
#  'hopeful': 20,
#  'emerging': 22,
#  'war': 216,
#  'akin': 6,
#  'betamax': 11,
#  'vhs': 8,
#  'resolved': 19,
#  'come': 466,
#  'huge': 210,
#  'libraries': 24,
#  'current': 274,
#  'big': 415,
#  'boost': 157,
#  'battle': 123,
#  'supremacy': 4,
#  'industry': 424,
#  'crucial': 71,
#  'film': 890,
#  'terms': 116,
#  'technical': 76,
#  'requirement': 12,
#  'development': 181,
#  'demands': 48,
#  'advanced': 28,
#  'technologies': 116,
#  'heilmann': 2,
#  'officer': 66,
#  'universal': 35,
#  'capacity': 76,
#  'performance': 232,
#  'internet': 309,
#  'connectivity': 8,
#  'ea': 39,
#  'developer': 17,
#  'publisher': 16,
#  'delivery': 26,
#  'vital': 70,
#  'functionality': 8,
#  'interactivity': 5,
#  'kinds': 14,
#  'projects': 69,
#  'planning': 101,
#  'recently': 185,
#  'using': 330,
#  'playstations': 2,
#  'ravenous': 2,
#  'graphics': 55,
#  'titles': 109,
#  'especially': 95,
#  'pcs': 118,
#  'focused': 46,
#  'deliver': 76,
#  'textures': 5,
#  'deeper': 11,
#  'levels': 118,
#  'delivering': 23,
#  'resolution': 36,
#  'playback': 12,
#  'moving': 79,
#  'forward': 193,
#  'increased': 115,
#  'immersion': 3,
#  'really': 384,
#  'creating': 61,
#  'involves': 14,
#  'complicated': 10,
#  'models': 70,
#  'increasing': 77,
#  'frame': 9,
#  'rate': 246,
#  'getting': 229,
#  'immersive': 13,
#  'experience': 121,
#  'fitting': 9,
#  'means': 223,
#  'compressing': 2,
#  'lost': 305,
#  'photo': 30,
#  'real': 338,
#  'capability': 22,
#  'limiting': 9,
#  'thrilled': 10,
#  'build': 113,
#  'environments': 8,
#  'currently': 263,
#  'intensive': 9,
#  'pc': 193,
#  'require': 32,
#  'multiple': 30,
#  'installation': 8,
#  'cut': 285,
#  'likewise': 3,
#  'consoles': 55,
#  'rely': 28,
#  'single': 184,
#  'mean': 166,
#  'won': 597,
#  'backing': 54,
#  'mgm': 9,
#  'disney': 37,
#  'buena': 3,
#  'vista': 3,
#  'dell': 12,
#  'lg': 30,
#  'samsung': 26,
#  'phillips': 43,
#  'paramount': 16,
#  'warner': 26,
#  'bros': 10,
#  'benefits': 72,
#  'apparent': 23,
#  'obvious': 44,
#  'jim': 31,
#  'cardwell': 4,
#  'president': 333,
#  'home': 663,
#  'rapid': 33,
#  'time': 1322,
#  'dependability': 2,
#  'factors': 28,
#  'choosing': 10,
#  'formats': 28,
#  'courting': 7,
#  'discussions': 34,
#  'ces': 37,
#  'largest': 149,
#  'runs': 56,
#  'pig': 9,
#  'poster': 46,
#  'anti': 297,
#  'semitic': 11,
#  'semitism': 6,
#  'depicting': 1,
#  'oliver': 48,
#  'letwin': 38,
#  'jewish': 42,
#  'flying': 44,
#  'pigs': 16,
#  'prospective': 10,
#  'andrew': 87,
#  'mennear': 3,
#  'finchley': 1,
#  'contains': 26,
#  'large': 161,
#  'community': 128,
#  'branded': 30,
#  'tasteless': 1,
#  'offensive': 21,
#  'shows': 168,
#  'men': 231,
#  'faces': 91,
#  'superimposed': 1,
#  'winged': 1,
#  'designs': 10,
#  'mailed': 8,
#  'asked': 205,
#  'favourite': 110,
#  'sent': 152,
#  'mail': 224,
#  'friend': 43,
#  'shocked': 24,
#  'image': 61,
#  'shown': 122,
#  'friends': 83,
#  'similarly': 23,
#  'horrified': 3,
#  'distasteful': 1,
#  'person': 106,
#  'associated': 48,
#  'deliberate': 9,
#  'intent': 17,
#  'sort': 80,
#  'things': 229,
#  'cause': 65,
#  'offence': 39,
#  'clearly': 73,
#  'wasn': 65,
#  'thought': 262,
#  'possible': 211,
#  'posters': 35,
#  'designed': 111,
#  'maximum': 25,
#  'overstepped': 1,
#  'mark': 224,
#  'withdrawn': 18,
#  'particularly': 127,
#  'insensitive': 4,
#  'holocaust': 11,
#  'difficult': 179,
#  'denied': 157,
#  'james': 117,
#  'report': 393,
#  'savings': 61,
#  'published': 90,
#  'fly': 66,
#  'point': 239,
#  'concentrating': 14,
#  'issues': 201,
#  'matter': 105,
#  'controlled': 47,
#  'immigration': 141,
#  'fooled': 4,
#  'costin': 3,
#  'aims': 52,
#  'comeback': 42,
#  'jamie': 77,
#  'paralysed': 9,
#  'way': 740,
#  'recalls': 6,
#  'car': 157,
#  'accident': 28,
#  'occurred': 15,
#  'days': 280,
#  'scheduled': 35,
#  'step': 123,
#  'olympic': 152,
#  'stadium': 84,
#  'walk': 40,
#  'ironic': 10,
#  'chuckle': 2,
#  'talks': 150,
#  'immediate': 34,
#  'thoughts': 14,
#  'lorry': 2,
#  'driving': 55,
#  'wrong': 134,
#  'road': 96,
#  'ploughed': 6,
#  'rental': 8,
#  'lot': 317,
#  'pain': 19,
#  'guessed': 4,
#  'toes': 1,
#  'broken': 75,
#  'waterford': 2,
#  'man': 296,
#  'thinking': 61,
#  'maybe': 57,
#  'cortisone': 1,
#  'injection': 12,
#  'know': 360,
#  'felt': 106,
#  'muscles': 4,
#  'ripped': 5,
#  'pelvis': 1,
#  'therapy': 3,
#  'ultra': 8,
#  'hopefully': 47,
#  'd': 67,
#  'knew': 72,
#  'certainty': 6,
#  'places': 73,
#  'vertebrae': 2,
#  'exploded': 7,
#  'fierce': 24,
#  'lucky': 19,
#  ...}

# %%
def word_freq_distribution(word_counts):
    freq_dist = {}
    max_freq = max(word_counts.values())
    for word in word_counts.keys():  
        freq_dist[word] = (word_counts[word]/max_freq)
    return freq_dist

freq_dist = word_freq_distribution(word_counts)
freq_dist
# Out:
# {'tate': 0.0028945554789800137,
#  'lyle': 0.0004135079255685734,
#  'boss': 0.02219159200551344,
#  'bags': 0.0008270158511371468,
#  'award': 0.04011026878015162,
#  'chief': 0.06340454858718125,
#  'executive': 0.04328049620951068,
#  'named': 0.01791867677463818,
#  'european': 0.07236388697450034,
#  'businessman': 0.0008270158511371468,
#  'year': 0.31840110268780153,
#  'leading': 0.020813232253618193,
#  'business': 0.05403170227429359,
#  'magazine': 0.013783597518952447,
#  'iain': 0.0005513439007580978,
#  'ferguson': 0.012405237767057202,
#  'awarded': 0.004962095106822881,
#  'title': 0.02991040661612681,
#  'publication': 0.0028945554789800137,
#  'forbes': 0.0005513439007580978,
#  'returning': 0.004962095106822881,
#  'uk': 0.1536871123363198,
#  'venerable': 0.0004135079255685734,
#  'manufacturers': 0.00647829083390765,
#  'country': 0.07277739490006892,
#  'companies': 0.05899379738111647,
#  'sugar': 0.0009648518263266712,
#  'group': 0.06864231564438318,
#  'absent': 0.0013783597518952446,
#  'ftse': 0.001516195727084769,
#  'seven': 0.019986216402481046,
#  'years': 0.13824948311509305,
#  'mr': 0.41419710544452104,
#  'helped': 0.019297036526533425,
#  'return': 0.03556168159889731,
#  'growth': 0.06436940041350793,
#  'shares': 0.03804272915230875,
#  'leapt': 0.0005513439007580978,
#  'boosted': 0.004962095106822881,
#  'firming': 0.00013783597518952445,
#  'prices': 0.03983459682977257,
#  'sales': 0.06809097174362509,
#  'artificial': 0.001791867677463818,
#  'sweeteners': 0.0009648518263266712,
#  'sagging': 0.00013783597518952445,
#  'stock': 0.02494831150930393,
#  'price': 0.029772570640937284,
#  'hiatus': 0.0004135079255685734,
#  'britain': 0.06202618883528601,
#  'returned': 0.008407994486560993,
#  'vaunted': 0.0002756719503790489,
#  'index': 0.009924190213645762,
#  'said': 1.0,
#  'took': 0.050447966919365955,
#  'helm': 0.0012405237767057202,
#  'company': 0.09455547898001378,
#  'spending': 0.0388697450034459,
#  'career': 0.025775327360441073,
#  'consumer': 0.030048242591316332,
#  'goods': 0.00799448656099242,
#  'giant': 0.021778084079944866,
#  'unilever': 0.001791867677463818,
#  'original': 0.01764300482425913,
#  'member': 0.016815988973121986,
#  'historic': 0.0028945554789800137,
#  'ft': 0.0024810475534114405,
#  'operates': 0.00399724328049621,
#  'factories': 0.002343211578221916,
#  'additional': 0.005099931082012405,
#  'production': 0.027015851137146794,
#  'facilities': 0.0037215713301171605,
#  'countries': 0.04300482425913164,
#  'previous': 0.025499655410062026,
#  'winners': 0.014059269469331495,
#  'include': 0.032667126119917296,
#  'royal': 0.008545830461750517,
#  'bank': 0.052377670572019294,
#  'scotland': 0.03528600964851826,
#  'fred': 0.0008270158511371468,
#  'goodwin': 0.00013783597518952445,
#  'vodafone': 0.00647829083390765,
#  'chris': 0.009235010337698139,
#  'gent': 0.00013783597518952445,
#  'halo': 0.006340454858718126,
#  'sells': 0.0016540317022742937,
#  'million': 0.07980702963473467,
#  'copies': 0.01144038594073053,
#  'microsoft': 0.038180565127498275,
#  'celebrating': 0.001516195727084769,
#  'bumper': 0.0008270158511371468,
#  'xbox': 0.011164713990351481,
#  'sci': 0.001516195727084769,
#  'fi': 0.009372846312887664,
#  'shooter': 0.0019297036526533425,
#  'game': 0.12005513439007581,
#  'sold': 0.03197794624396968,
#  'worldwide': 0.010613370089593384,
#  'went': 0.03749138525155066,
#  'sale': 0.03363197794624397,
#  'mid': 0.00771881461061337,
#  'november': 0.02935906271536871,
#  'proved': 0.01047553411440386,
#  'popular': 0.023983459682977257,
#  'online': 0.04755341144038594,
#  'gamers': 0.011991729841488628,
#  'notching': 0.0002756719503790489,
#  'record': 0.0585802894555479,
#  'hours': 0.019572708476912472,
#  'playing': 0.04066161268090972,
#  'live': 0.026326671261199173,
#  'according': 0.058166781529979325,
#  'members': 0.028532046864231563,
#  'played': 0.03859407305306685,
#  'average': 0.018470020675396277,
#  'minutes': 0.030737422467263957,
#  'session': 0.006202618883528601,
#  'sequel': 0.006202618883528601,
#  'best': 0.13425223983459683,
#  'selling': 0.016540317022742935,
#  'need': 0.05775327360441075,
#  'speed': 0.018607856650585803,
#  'underground': 0.003170227429359063,
#  'inched': 0.0005513439007580978,
#  'ahead': 0.03680220537560303,
#  'competition': 0.0259131633356306,
#  'slot': 0.0027567195037904893,
#  'official': 0.019848380427291524,
#  'games': 0.08573397656788422,
#  'charts': 0.008132322536181943,
#  'racing': 0.00399724328049621,
#  'moved': 0.014610613370089594,
#  'spot': 0.011853893866299104,
#  'place': 0.05554789800137836,
#  'nudging': 0.0002756719503790489,
#  'gta': 0.0016540317022742937,
#  'san': 0.009648518263266712,
#  'andreas': 0.003170227429359063,
#  'second': 0.0833907649896623,
#  'dropped': 0.014059269469331495,
#  'half': 0.06533425223983459,
#  'life': 0.052377670572019294,
#  'fell': 0.021364576154376293,
#  'number': 0.10475534114403859,
#  'week': 0.08187456926257754,
#  'new': 0.2726395589248794,
#  'releases': 0.003170227429359063,
#  'goldeneye': 0.0008270158511371468,
#  'rogue': 0.0019297036526533425,
#  'agent': 0.005789110957960027,
#  'killzone': 0.00013783597518952445,
#  'failed': 0.02439696760854583,
#  'make': 0.1302549965541006,
#  'debuting': 0.0002756719503790489,
#  'respectively': 0.0033080634045485873,
#  'numbers': 0.018332184700206755,
#  'warcraft': 0.0016540317022742937,
#  'fans': 0.02866988283942109,
#  'settling': 0.0006891798759476223,
#  'world': 0.16554100620261888,
#  'opening': 0.020261888352860098,
#  'day': 0.0642315644383184,
#  'massive': 0.012267401791867678,
#  'multi': 0.005926946933149552,
#  'player': 0.04259131633356306,
#  'players': 0.07222605099931081,
#  'signed': 0.016264645072363887,
#  'play': 0.07884217780840799,
#  'evening': 0.008270158511371467,
#  'forcing': 0.0019297036526533425,
#  'blizzard': 0.0004135079255685734,
#  'add': 0.01323225361819435,
#  'servers': 0.00523776705720193,
#  'cope': 0.005926946933149552,
#  'influx': 0.0002756719503790489,
#  'turns': 0.004548587181254307,
#  'stand': 0.019710544452101998,
#  'persistent': 0.002067539627842867,
#  'inhabit': 0.00013783597518952445,
#  'just': 0.1319090282563749,
#  'visit': 0.00895933838731909,
#  'europe': 0.05678842177808408,
#  'waiting': 0.01047553411440386,
#  'january': 0.04259131633356306,
#  'hear': 0.006891798759476223,
#  'mitts': 0.00013783597518952445,
#  'nintendo': 0.012405237767057202,
#  'handheld': 0.008270158511371467,
#  'device': 0.015575465196416265,
#  'ds': 0.008132322536181943,
#  'says': 0.0946933149552033,
#  'gamesindustry': 0.0002756719503790489,
#  'biz': 0.0008270158511371468,
#  'david': 0.03542384562370779,
#  'yarnton': 0.0004135079255685734,
#  'general': 0.050447966919365955,
#  'manager': 0.030323914541695383,
#  'told': 0.12556857339765679,
#  'press': 0.018470020675396277,
#  'conference': 0.02191592005513439,
#  'look': 0.04107512060647829,
#  'details': 0.01543762922122674,
#  'launch': 0.021778084079944866,
#  'sunday': 0.034734665747760164,
#  'goes': 0.0129565816678153,
#  'japan': 0.030048242591316332,
#  'december': 0.041764300482425916,
#  'share': 0.032529290144727774,
#  'gaming': 0.02343211578221916,
#  'market': 0.09676085458304617,
#  'expected': 0.0698828394210889,
#  'sell': 0.018470020675396277,
#  'march': 0.03170227429359063,
#  'msps': 0.0012405237767057202,
#  'renewed': 0.0028945554789800137,
#  'climate': 0.005099931082012405,
#  'warning': 0.01171605789110958,
#  'change': 0.035975189524465885,
#  'completely': 0.009372846312887664,
#  'control': 0.0377670572019297,
#  'decades': 0.004135079255685734,
#  'scottish': 0.019021364576154377,
#  'environment': 0.01019986216402481,
#  'protection': 0.014472777394900068,
#  'agency': 0.018332184700206755,
#  'committee': 0.025361819434872503,
#  'experts': 0.012818745692625776,
#  'giving': 0.014059269469331495,
#  'evidence': 0.02494831150930393,
#  'subject': 0.010889042039972433,
#  'parliament': 0.021778084079944866,
#  'officials': 0.01791867677463818,
#  'believe': 0.03749138525155066,
#  'nuclear': 0.007029634734665747,
#  'energy': 0.017505168849069608,
#  'wind': 0.0019297036526533425,
#  'farms': 0.0013783597518952446,
#  'better': 0.04906960716747071,
#  'options': 0.006340454858718126,
#  'trying': 0.026188835286009647,
#  'tackle': 0.01171605789110958,
#  'global': 0.027291523087525846,
#  'warming': 0.0009648518263266712,
#  'solutions': 0.0034458993797381117,
#  'suggested': 0.014886285320468642,
#  'conservationists': 0.00013783597518952445,
#  'reducing': 0.005513439007580979,
#  'internal': 0.00399724328049621,
#  'air': 0.016402481047553413,
#  'travel': 0.010889042039972433,
#  'boosting': 0.0034458993797381117,
#  'electric': 0.001516195727084769,
#  'trains': 0.0016540317022742937,
#  'inquiry': 0.011302549965541007,
#  'impact': 0.01819434872501723,
#  'sepa': 0.0006891798759476223,
#  'attempting': 0.003170227429359063,
#  'curb': 0.0012405237767057202,
#  'gases': 0.0002756719503790489,
#  'pollution': 0.0006891798759476223,
#  'transport': 0.009924190213645762,
#  'emissions': 0.0013783597518952446,
#  'increases': 0.008270158511371467,
#  'ecologists': 0.00013783597518952445,
#  'accept': 0.009372846312887664,
#  'significant': 0.014334941419710544,
#  'intrusion': 0.0004135079255685734,
#  'likely': 0.04521019986216403,
#  'power': 0.03432115782219159,
#  'needed': 0.030048242591316332,
#  'possibly': 0.003859407305306685,
#  'predict': 0.004548587181254307,
#  'methods': 0.0024810475534114405,
#  'remain': 0.02039972432804962,
#  'sources': 0.006616126809097175,
#  'studying': 0.003170227429359063,
#  'seas': 0.0005513439007580978,
#  'west': 0.019710544452101998,
#  'coast': 0.0028945554789800137,
#  'forecast': 0.009648518263266712,
#  'devastating': 0.0012405237767057202,
#  'weather': 0.005651274982770503,
#  'type': 0.007580978635423846,
#  'caused': 0.009372846312887664,
#  'havoc': 0.00013783597518952445,
#  'month': 0.05775327360441075,
#  'predicted': 0.013370089593383873,
#  'damaging': 0.004686423156443832,
#  'storms': 0.0006891798759476223,
#  'frequent': 0.0005513439007580978,
#  'researchers': 0.006202618883528601,
#  'university': 0.018470020675396277,
#  'highlands': 0.0008270158511371468,
#  'islands': 0.002618883528600965,
#  'southampton': 0.005789110957960027,
#  'looking': 0.036250861474844936,
#  'wave': 0.0037215713301171605,
#  'heights': 0.0009648518263266712,
#  'atlantic': 0.002618883528600965,
#  'project': 0.024121295658166782,
#  'conducted': 0.005789110957960027,
#  'jointly': 0.002067539627842867,
#  'environmental': 0.00647829083390765,
#  'research': 0.040248104755341144,
#  'institute': 0.007856650585802894,
#  'thurso': 0.0002756719503790489,
#  'uhi': 0.00013783597518952445,
#  'millennium': 0.0033080634045485873,
#  'network': 0.03059958649207443,
#  'oceanography': 0.00013783597518952445,
#  'centre': 0.027429359062715368,
#  'scientists': 0.002618883528600965,
#  'carried': 0.008407994486560993,
#  'series': 0.03514817367332874,
#  'studies': 0.00399724328049621,
#  'including': 0.05609924190213646,
#  'use': 0.08063404548587182,
#  'satellites': 0.0002756719503790489,
#  'assess': 0.00399724328049621,
#  'hebrides': 0.00013783597518952445,
#  'pavey': 0.0012405237767057202,
#  'focuses': 0.0011026878015161956,
#  'indoor': 0.012267401791867678,
#  'success': 0.027015851137146794,
#  'jo': 0.0009648518263266712,
#  'miss': 0.008545830461750517,
#  'view': 0.017780840799448656,
#  'great': 0.05306685044796692,
#  'edinburgh': 0.01075120606478291,
#  'international': 0.055823569951757405,
#  'cross': 0.01612680909717436,
#  'focus': 0.01695382494831151,
#  'preparing': 0.004548587181254307,
#  'championships': 0.011578221915920055,
#  'old': 0.0658855961405927,
#  'hayley': 0.0009648518263266712,
#  'yelling': 0.002343211578221916,
#  'justyna': 0.00013783597518952445,
#  'bak': 0.00013783597518952445,
#  'prefers': 0.0005513439007580978,
#  'race': 0.024534803583735356,
#  'track': 0.015713301171605788,
#  'winning': 0.03390764989662302,
#  'bronze': 0.002343211578221916,
#  'm': 0.09455547898001378,
#  'wary': 0.0012405237767057202,
#  'injuries': 0.006202618883528601,
#  'concentrate': 0.002067539627842867,
#  'season': 0.03749138525155066,
#  'don': 0.06119917298414886,
#  'run': 0.04355616815988973,
#  'hills': 0.0011026878015161956,
#  'training': 0.016264645072363887,
#  'came': 0.04962095106822881,
#  'fifth': 0.009786354238456236,
#  'athens': 0.01392143349414197,
#  'olympics': 0.009097174362508615,
#  'british': 0.07470709855272226,
#  'team': 0.05527222605099931,
#  'win': 0.0844934527911785,
#  'silver': 0.004686423156443832,
#  'medal': 0.007029634734665747,
#  'heringsdorf': 0.00013783597518952445,
#  'start': 0.05113714679531358,
#  'boston': 0.00399724328049621,
#  'stuttgart': 0.0005513439007580978,
#  'end': 0.07126119917298415,
#  'tories': 0.03349414197105444,
#  'reject': 0.003170227429359063,
#  'rethink': 0.001791867677463818,
#  'axed': 0.0016540317022742937,
#  'mp': 0.023983459682977257,
#  'sacked': 0.0034458993797381117,
#  'howard': 0.050172294968986904,
#  'flight': 0.006753962784286699,
#  'local': 0.036940041350792555,
#  'conservative': 0.019572708476912472,
#  'association': 0.02067539627842867,
#  'insisted': 0.01598897312198484,
#  'candidate': 0.005926946933149552,
#  'election': 0.0912474155754652,
#  'russell': 0.002343211578221916,
#  'tanguay': 0.0004135079255685734,
#  'arundel': 0.0002756719503790489,
#  'south': 0.035699517574086834,
#  'downs': 0.0005513439007580978,
#  'ineligible': 0.0004135079255685734,
#  'seeking': 0.008545830461750517,
#  'substitute': 0.0019297036526533425,
#  'news': 0.07139903514817367,
#  'comes': 0.025361819434872503,
#  'despite': 0.046037215713301174,
#  'allies': 0.0037215713301171605,
#  'saying': 0.04424534803583735,
#  'support': 0.03762922122674018,
#  'hold': 0.027980702963473467,
#  'meeting': 0.03335630599586492,
#  'discuss': 0.008132322536181943,
#  'fate': 0.001791867677463818,
#  'landed': 0.002618883528600965,
#  'trouble': 0.009510682288077188,
#  'remarks': 0.0037215713301171605,
#  'tory': 0.03762922122674018,
#  'tax': 0.059407305306685046,
#  'plans': 0.06698828394210889,
#  'quit': 0.00895933838731909,
#  'deputy': 0.009510682288077188,
#  'chairman': 0.03170227429359063,
#  'apparently': 0.003032391454169538,
#  'suggesting': 0.004135079255685734,
#  'planned': 0.012680909717436252,
#  'extra': 0.018470020675396277,
#  'cuts': 0.01764300482425913,
#  'wants': 0.024810475534114404,
#  'continue': 0.030186078566505858,
#  'headquarters': 0.0037215713301171605,
#  'longer': 0.016402481047553413,
#  'approved': 0.005375603032391455,
#  'backed': 0.0129565816678153,
#  'tuesday': 0.030186078566505858,
#  'party': 0.08683666436940041,
#  'process': 0.01764300482425913,
#  'selecting': 0.0009648518263266712,
#  'similar': 0.021088904203997245,
#  'comments': 0.017367332873880082,
#  'friday': 0.02784286698828394,
#  'dissent': 0.0005513439007580978,
#  'continues': 0.009648518263266712,
#  'councillors': 0.0011026878015161956,
#  'met': 0.014886285320468642,
#  'afternoon': 0.003170227429359063,
#  'did': 0.07415575465196417,
#  'comment': 0.012405237767057202,
#  'left': 0.04107512060647829,
#  'unless': 0.009097174362508615,
#  'instructs': 0.00013783597518952445,
#  'extraordinary': 0.003170227429359063,
#  'egm': 0.0002756719503790489,
#  'consulting': 0.001791867677463818,
#  'lawyers': 0.007443142660234321,
#  'bbc': 0.10723638869745003,
#  'selected': 0.004548587181254307,
#  'like': 0.121157822191592,
#  'dispose': 0.0002756719503790489,
#  'supporters': 0.011991729841488628,
#  'say': 0.08022053756030324,
#  'signatures': 0.0004135079255685734,
#  'trigger': 0.0019297036526533425,
#  'rules': 0.025361819434872503,
#  'leader': 0.03969676085458305,
#  'argues': 0.004686423156443832,
#  'ensuring': 0.004824259131633356,
#  'honesty': 0.0011026878015161956,
#  'thing': 0.027705031013094416,
#  'private': 0.018056512749827704,
#  'public': 0.07677463818056512,
#  'labour': 0.11082012405237766,
#  'campaign': 0.04576154376292212,
#  'coordinator': 0.0012405237767057202,
#  'alan': 0.015713301171605788,
#  'milburn': 0.009510682288077188,
#  'turmoil': 0.0002756719503790489,
#  'exposed': 0.0024810475534114405,
#  'hidden': 0.004135079255685734,
#  'claiming': 0.009372846312887664,
#  'senior': 0.02039972432804962,
#  'obsessively': 0.0002756719503790489,
#  'committed': 0.008821502412129565,
#  'cutting': 0.009924190213645762,
#  'liberal': 0.024121295658166782,
#  'democrat': 0.009924190213645762,
#  'matthew': 0.004548587181254307,
#  'taylor': 0.012543073742246726,
#  'whilst': 0.005513439007580979,
#  'disagree': 0.0009648518263266712,
#  'views': 0.008407994486560993,
#  'sack': 0.001791867677463818,
#  'somebody': 0.0037215713301171605,
#  'telling': 0.006202618883528601,
#  'truth': 0.004962095106822881,
#  'emerged': 0.007029634734665747,
#  'suspended': 0.011026878015161957,
#  'slough': 0.0008270158511371468,
#  'constituency': 0.004824259131633356,
#  'refusing': 0.001791867677463818,
#  'deselect': 0.0002756719503790489,
#  'adrian': 0.0016540317022742937,
#  'hilton': 0.0008270158511371468,
#  'abandoned': 0.0024810475534114405,
#  'signing': 0.00647829083390765,
#  'maastricht': 0.00013783597518952445,
#  'treaty': 0.0024810475534114405,
#  'john': 0.035975189524465885,
#  'major': 0.036940041350792555,
#  'government': 0.15988973121984837,
#  'act': 0.029083390764989663,
#  'treason': 0.0002756719503790489,
#  'catholic': 0.003032391454169538,
#  'herald': 0.001516195727084769,
#  'highlighted': 0.00523776705720193,
#  'articles': 0.002343211578221916,
#  'wrote': 0.008545830461750517,
#  'role': 0.03900758097863542,
#  'catholicism': 0.00013783597518952445,
#  'union': 0.027705031013094416,
#  'chosen': 0.008407994486560993,
#  'fight': 0.01874569262577533,
#  'seat': 0.006340454858718126,
#  'robert': 0.016264645072363887,
#  'oulds': 0.00013783597518952445,
#  'pictured': 0.0004135079255685734,
#  'range': 0.02095106822880772,
#  'guns': 0.001516195727084769,
#  'hunting': 0.011164713990351481,
#  'knife': 0.002343211578221916,
#  'placed': 0.005789110957960027,
#  'status': 0.005375603032391455,
#  'spokesman': 0.04906960716747071,
#  'considering': 0.007856650585802894,
#  'taking': 0.040248104755341144,
#  'legal': 0.039421088904203996,
#  'action': 0.0456237077877326,
#  'deposal': 0.00013783597518952445,
#  'learned': 0.0024810475534114405,
#  'final': 0.05223983459682977,
#  'decision': 0.04672639558924879,
#  'website': 0.03335630599586492,
#  'monday': 0.028532046864231563,
#  'people': 0.28187456926257753,
#  'central': 0.01543762922122674,
#  'office': 0.04796691936595451,
#  'behaving': 0.0011026878015161956,
#  'little': 0.03845623707787733,
#  'dictators': 0.0002756719503790489,
#  'seemingly': 0.0012405237767057202,
#  'ordinary': 0.004962095106822881,
#  'treated': 0.0042729152308752585,
#  'contempt': 0.0012405237767057202,
#  'try': 0.03514817367332874,
#  'contact': 0.006202618883528601,
#  'lib': 0.024810475534114404,
#  'dems': 0.014059269469331495,
#  'poll': 0.016402481047553413,
#  'set': 0.10503101309441765,
#  'results': 0.02039972432804962,
#  'council': 0.02866988283942109,
#  'polls': 0.0034458993797381117,
#  'frontbenchers': 0.00013783597518952445,
#  'ed': 0.002343211578221916,
#  'davey': 0.0009648518263266712,
#  'speaking': 0.016815988973121986,
#  'launched': 0.02095106822880772,
#  'elections': 0.0129565816678153,
#  'held': 0.035699517574086834,
#  'english': 0.014886285320468642,
#  'areas': 0.018056512749827704,
#  'flagship': 0.0013783597518952446,
#  'pledge': 0.004135079255685734,
#  'replace': 0.009648518263266712,
#  'income': 0.014472777394900068,
#  'pay': 0.04011026878015162,
#  'sums': 0.0027567195037904893,
#  'coming': 0.028945554789800137,
#  'going': 0.08711233631977947,
#  'votes': 0.00647829083390765,
#  'seats': 0.007305306685044797,
#  'think': 0.08215024121295658,
#  'charles': 0.02343211578221916,
#  'kennedy': 0.018607856650585803,
#  'couldn': 0.00523776705720193,
#  'stronger': 0.00771881461061337,
#  'endorsement': 0.00013783597518952445,
#  'attacks': 0.02164024810475534,
#  'later': 0.040385940730530666,
#  'budget': 0.03666436940041351,
#  'michael': 0.03955892487939352,
#  'dismissed': 0.00647829083390765,
#  'gordon': 0.02039972432804962,
#  'brown': 0.06492074431426602,
#  'vote': 0.027429359062715368,
#  'simple': 0.010337698139214336,
#  'fact': 0.02370778773259821,
#  'taxes': 0.01888352860096485,
#  'plug': 0.0012405237767057202,
#  'financial': 0.03638869745003446,
#  'black': 0.021088904203997245,
#  'hole': 0.0034458993797381117,
#  'chancellor': 0.037215713301171606,
#  'hid': 0.0004135079255685734,
#  'rises': 0.008407994486560993,
#  'hard': 0.03997243280496209,
#  'working': 0.037077877325982084,
#  'families': 0.011164713990351481,
#  'faltering': 0.0011026878015161956,
#  'package': 0.006753962784286699,
#  'measures': 0.014059269469331495,
#  'added': 0.10103376981392144,
#  'good': 0.0890420399724328,
#  'interests': 0.00895933838731909,
#  'mockingly': 0.00013783597518952445,
#  'welcoming': 0.0005513439007580978,
#  'accuse': 0.0013783597518952446,
#  'hand': 0.016815988973121986,
#  'away': 0.04328049620951068,
#  'urged': 0.010062026188835286,
#  'admit': 0.0019297036526533425,
#  'responsible': 0.01019986216402481,
#  'dragging': 0.0008270158511371468,
#  'millions': 0.01543762922122674,
#  'net': 0.0625775327360441,
#  'stamp': 0.0033080634045485873,
#  'duty': 0.010337698139214336,
#  'inheritance': 0.0012405237767057202,
#  'hide': 0.00399724328049621,
#  'crippling': 0.0002756719503790489,
#  'inevitable': 0.0016540317022742937,
#  'wins': 0.013645761543762923,
#  'accused': 0.020537560303239145,
#  'running': 0.027705031013094416,
#  'problems': 0.03197794624396968,
#  'faced': 0.009648518263266712,
#  'answer': 0.012543073742246726,
#  'spend': 0.01695382494831151,
#  'waste': 0.007305306685044797,
#  'liked': 0.002067539627842867,
#  'rattle': 0.0002756719503790489,
#  'magical': 0.0006891798759476223,
#  'balances': 0.0005513439007580978,
#  'conjured': 0.00013783597518952445,
#  'bid': 0.029221226740179188,
#  'convince': 0.0009648518263266712,
#  'nation': 0.009372846312887664,
#  'finances': 0.005375603032391455,
#  'dodgy': 0.0011026878015161956,
#  'brought': 0.017367332873880082,
#  'dossier': 0.0016540317022742937,
#  'publishing': 0.002343211578221916,
#  'based': 0.057891109579600274,
#  'propose': 0.0011026878015161956,
#  'borrow': 0.001791867677463818,
#  'billion': 0.012129565816678152,
#  'prudence': 0.0004135079255685734,
#  'forecasts': 0.00771881461061337,
#  'surpluses': 0.0004135079255685734,
#  'prime': 0.04521019986216403,
#  'minister': 0.07732598208132323,
#  'weapons': 0.0042729152308752585,
#  'mass': 0.007305306685044797,
#  'destruction': 0.0042729152308752585,
#  'rebate': 0.003170227429359063,
#  'pensioners': 0.0044107512060647825,
#  'offering': 0.013094417643004824,
#  'police': 0.03611302549965541,
#  'streets': 0.005513439007580979,
#  'hospitals': 0.004686423156443832,
#  'cleaner': 0.0013783597518952446,
#  'parents': 0.014472777394900068,
#  'teachers': 0.00399724328049621,
#  'discipline': 0.0042729152308752585,
#  'skills': 0.008407994486560993,
#  'wanted': 0.026878015161957272,
#  'schools': 0.016402481047553413,
#  'face': 0.037077877325982084,
#  'clear': 0.03197794624396968,
#  'choice': 0.02343211578221916,
#  'higher': 0.02563749138525155,
#  'lower': 0.01667815299793246,
#  'value': 0.019710544452101998,
#  'money': 0.06064782908339077,
#  'conservatives': 0.01543762922122674,
#  'battleground': 0.0005513439007580978,
#  'bring': 0.01874569262577533,
#  'concluded': 0.0037215713301171605,
#  'loud': 0.0006891798759476223,
#  'cheering': 0.0004135079255685734,
#  'blu': 0.0044107512060647825,
#  'ray': 0.015575465196416265,
#  'dvd': 0.023018607856650587,
#  'format': 0.009372846312887664,
#  'generation': 0.01764300482425913,
#  'rival': 0.014748449345279118,
#  'backers': 0.0012405237767057202,
#  'firms': 0.05458304617505169,
#  'sony': 0.026188835286009647,
#  'competing': 0.007167470709855272,
#  'toshiba': 0.00399724328049621,
#  'nec': 0.001791867677463818,
#  'hd': 0.007580978635423846,
#  'future': 0.051412818745692625,
#  'films': 0.03556168159889731,
#  'thursday': 0.02370778773259821,
#  'giants': 0.0034458993797381117,
#  'electronic': 0.009786354238456236,
#  'arts': 0.006753962784286699,
#  'vivendi': 0.0024810475534114405,
#  'dvds': 0.008821502412129565,
#  'high': 0.07705031013094418,
#  'definition': 0.013645761543762923,
#  'video': 0.05003445899379738,
#  'sound': 0.013645761543762923,
#  'offers': 0.012543073742246726,
#  'incredible': 0.004135079255685734,
#  'quality': 0.01695382494831151,
#  'pictures': 0.011302549965541007,
#  'hollywood': 0.015851137146795313,
#  'studios': 0.009510682288077188,
#  'publishers': 0.002067539627842867,
#  'extremely': 0.00771881461061337,
#  'keen': 0.014472777394900068,
#  'exploit': 0.0028945554789800137,
#  'separate': 0.012267401791867678,
#  'electronics': 0.01144038594073053,
#  'las': 0.0042729152308752585,
#  'vegas': 0.004135079255685734,
#  'announced': 0.034734665747760164,
#  'technology': 0.07732598208132323,
#  'standard': 0.01819434872501723,
#  'images': 0.01543762922122674,
#  'greater': 0.011302549965541007,
#  'storage': 0.008683666436940041,
#  'richard': 0.013094417643004824,
#  'doherty': 0.0033080634045485873,
#  'panasonic': 0.0006891798759476223,
#  'laboratories': 0.0012405237767057202,
#  'pioneers': 0.0016540317022742937,
#  'utilising': 0.0005513439007580978,
#  'blue': 0.007305306685044797,
#  'laser': 0.0042729152308752585,
#  'optical': 0.0005513439007580978,
#  'disc': 0.0037215713301171605,
#  'times': 0.04203997243280496,
#  'today': 0.028807718814610615,
#  'able': 0.04314266023432116,
#  'store': 0.01047553411440386,
#  'gb': 0.00799448656099242,
#  'data': 0.044934527911784976,
#  'making': 0.04576154376292212,
#  'sure': 0.022329427980702962,
#  'discs': 0.002067539627842867,
#  'satisfy': 0.0012405237767057202,
#  'needs': 0.02095106822880772,
#  'ability': 0.013783597518952447,
#  'smaller': 0.009648518263266712,
#  'fit': 0.012129565816678152,
#  'camcorders': 0.0005513439007580978,
#  'hopeful': 0.0027567195037904893,
#  'emerging': 0.003032391454169538,
#  'war': 0.029772570640937284,
#  'akin': 0.0008270158511371468,
#  'betamax': 0.001516195727084769,
#  'vhs': 0.0011026878015161956,
#  'resolved': 0.002618883528600965,
#  'come': 0.0642315644383184,
#  'huge': 0.028945554789800137,
#  'libraries': 0.0033080634045485873,
#  'current': 0.0377670572019297,
#  'big': 0.057201929703652656,
#  'boost': 0.02164024810475534,
#  'battle': 0.01695382494831151,
#  'supremacy': 0.0005513439007580978,
#  'industry': 0.058442453480358376,
#  'crucial': 0.009786354238456236,
#  'film': 0.12267401791867677,
#  'terms': 0.01598897312198484,
#  'technical': 0.01047553411440386,
#  'requirement': 0.0016540317022742937,
#  'development': 0.02494831150930393,
#  'demands': 0.006616126809097175,
#  'advanced': 0.003859407305306685,
#  'technologies': 0.01598897312198484,
#  'heilmann': 0.0002756719503790489,
#  'officer': 0.009097174362508615,
#  'universal': 0.004824259131633356,
#  'capacity': 0.01047553411440386,
#  'performance': 0.03197794624396968,
#  'internet': 0.04259131633356306,
#  'connectivity': 0.0011026878015161956,
#  'ea': 0.005375603032391455,
#  'developer': 0.002343211578221916,
#  'publisher': 0.0022053756030323913,
#  'delivery': 0.003583735354927636,
#  'vital': 0.009648518263266712,
#  'functionality': 0.0011026878015161956,
#  'interactivity': 0.0006891798759476223,
#  'kinds': 0.0019297036526533425,
#  'projects': 0.009510682288077188,
#  'planning': 0.01392143349414197,
#  'recently': 0.025499655410062026,
#  'using': 0.04548587181254307,
#  'playstations': 0.0002756719503790489,
#  'ravenous': 0.0002756719503790489,
#  'graphics': 0.007580978635423846,
#  'titles': 0.015024121295658166,
#  'especially': 0.013094417643004824,
#  'pcs': 0.016264645072363887,
#  'focused': 0.006340454858718126,
#  'deliver': 0.01047553411440386,
#  'textures': 0.0006891798759476223,
#  'deeper': 0.001516195727084769,
#  'levels': 0.016264645072363887,
#  'delivering': 0.003170227429359063,
#  'resolution': 0.004962095106822881,
#  'playback': 0.0016540317022742937,
#  'moving': 0.010889042039972433,
#  'forward': 0.02660234321157822,
#  'increased': 0.015851137146795313,
#  'immersion': 0.0004135079255685734,
#  'really': 0.0529290144727774,
#  'creating': 0.008407994486560993,
#  'involves': 0.0019297036526533425,
#  'complicated': 0.0013783597518952446,
#  'models': 0.009648518263266712,
#  'increasing': 0.010613370089593384,
#  'frame': 0.0012405237767057202,
#  'rate': 0.03390764989662302,
#  'getting': 0.031564438318401104,
#  'immersive': 0.001791867677463818,
#  'experience': 0.01667815299793246,
#  'fitting': 0.0012405237767057202,
#  'means': 0.030737422467263957,
#  'compressing': 0.0002756719503790489,
#  'lost': 0.04203997243280496,
#  'photo': 0.004135079255685734,
#  'real': 0.04658855961405927,
#  'capability': 0.003032391454169538,
#  'limiting': 0.0012405237767057202,
#  'thrilled': 0.0013783597518952446,
#  'build': 0.015575465196416265,
#  'environments': 0.0011026878015161956,
#  'currently': 0.036250861474844936,
#  'intensive': 0.0012405237767057202,
#  'pc': 0.02660234321157822,
#  'require': 0.0044107512060647825,
#  'multiple': 0.004135079255685734,
#  'installation': 0.0011026878015161956,
#  'cut': 0.039283252929014474,
#  'likewise': 0.0004135079255685734,
#  'consoles': 0.007580978635423846,
#  'rely': 0.003859407305306685,
#  'single': 0.025361819434872503,
#  'mean': 0.02288077188146106,
#  'won': 0.08228807718814611,
#  'backing': 0.007443142660234321,
#  'mgm': 0.0012405237767057202,
#  'disney': 0.005099931082012405,
#  'buena': 0.0004135079255685734,
#  'vista': 0.0004135079255685734,
#  'dell': 0.0016540317022742937,
#  'lg': 0.004135079255685734,
#  'samsung': 0.003583735354927636,
#  'phillips': 0.005926946933149552,
#  'paramount': 0.0022053756030323913,
#  'warner': 0.003583735354927636,
#  'bros': 0.0013783597518952446,
#  'benefits': 0.009924190213645762,
#  'apparent': 0.003170227429359063,
#  'obvious': 0.006064782908339076,
#  'jim': 0.0042729152308752585,
#  'cardwell': 0.0005513439007580978,
#  'president': 0.045899379738111645,
#  'home': 0.09138525155065472,
#  'rapid': 0.004548587181254307,
#  'time': 0.18221915920055134,
#  'dependability': 0.0002756719503790489,
#  'factors': 0.003859407305306685,
#  'choosing': 0.0013783597518952446,
#  'formats': 0.003859407305306685,
#  'courting': 0.0009648518263266712,
#  'discussions': 0.004686423156443832,
#  'ces': 0.005099931082012405,
#  'largest': 0.020537560303239145,
#  'runs': 0.00771881461061337,
#  'pig': 0.0012405237767057202,
#  'poster': 0.006340454858718126,
#  'anti': 0.04093728463128877,
#  'semitic': 0.001516195727084769,
#  'semitism': 0.0008270158511371468,
#  'depicting': 0.00013783597518952445,
#  'oliver': 0.006616126809097175,
#  'letwin': 0.00523776705720193,
#  'jewish': 0.005789110957960027,
#  'flying': 0.006064782908339076,
#  'pigs': 0.0022053756030323913,
#  'prospective': 0.0013783597518952446,
#  'andrew': 0.011991729841488628,
#  'mennear': 0.0004135079255685734,
#  'finchley': 0.00013783597518952445,
#  'contains': 0.003583735354927636,
#  'large': 0.02219159200551344,
#  'community': 0.01764300482425913,
#  'branded': 0.004135079255685734,
#  'tasteless': 0.00013783597518952445,
#  'offensive': 0.0028945554789800137,
#  'shows': 0.02315644383184011,
#  'men': 0.03184011026878015,
#  'faces': 0.012543073742246726,
#  'superimposed': 0.00013783597518952445,
#  'winged': 0.00013783597518952445,
#  'designs': 0.0013783597518952446,
#  'mailed': 0.0011026878015161956,
#  'asked': 0.028256374913852515,
#  'favourite': 0.015161957270847692,
#  'sent': 0.02095106822880772,
#  'mail': 0.03087525844245348,
#  'friend': 0.005926946933149552,
#  'shocked': 0.0033080634045485873,
#  'image': 0.008407994486560993,
#  'shown': 0.016815988973121986,
#  'friends': 0.01144038594073053,
#  'similarly': 0.003170227429359063,
#  'horrified': 0.0004135079255685734,
#  'distasteful': 0.00013783597518952445,
#  'person': 0.014610613370089594,
#  'associated': 0.006616126809097175,
#  'deliberate': 0.0012405237767057202,
#  'intent': 0.002343211578221916,
#  'sort': 0.011026878015161957,
#  'things': 0.031564438318401104,
#  'cause': 0.00895933838731909,
#  'offence': 0.005375603032391455,
#  'clearly': 0.010062026188835286,
#  'wasn': 0.00895933838731909,
#  'thought': 0.03611302549965541,
#  'possible': 0.029083390764989663,
#  'posters': 0.004824259131633356,
#  'designed': 0.015299793246037216,
#  'maximum': 0.0034458993797381117,
#  'overstepped': 0.00013783597518952445,
#  'mark': 0.03087525844245348,
#  'withdrawn': 0.0024810475534114405,
#  'particularly': 0.017505168849069608,
#  'insensitive': 0.0005513439007580978,
#  'holocaust': 0.001516195727084769,
#  'difficult': 0.02467263955892488,
#  'denied': 0.02164024810475534,
#  'james': 0.01612680909717436,
#  'report': 0.05416953824948312,
#  'savings': 0.008407994486560993,
#  'published': 0.012405237767057202,
#  'fly': 0.009097174362508615,
#  'point': 0.03294279807029635,
#  'concentrating': 0.0019297036526533425,
#  'issues': 0.027705031013094416,
#  'matter': 0.014472777394900068,
#  'controlled': 0.00647829083390765,
#  'immigration': 0.01943487250172295,
#  'fooled': 0.0005513439007580978,
#  'costin': 0.0004135079255685734,
#  'aims': 0.007167470709855272,
#  'comeback': 0.005789110957960027,
#  'jamie': 0.010613370089593384,
#  'paralysed': 0.0012405237767057202,
#  'way': 0.1019986216402481,
#  'recalls': 0.0008270158511371468,
#  'car': 0.02164024810475534,
#  'accident': 0.003859407305306685,
#  'occurred': 0.002067539627842867,
#  'days': 0.03859407305306685,
#  'scheduled': 0.004824259131633356,
#  'step': 0.01695382494831151,
#  'olympic': 0.02095106822880772,
#  'stadium': 0.011578221915920055,
#  'walk': 0.005513439007580979,
#  'ironic': 0.0013783597518952446,
#  'chuckle': 0.0002756719503790489,
#  'talks': 0.02067539627842867,
#  'immediate': 0.004686423156443832,
#  'thoughts': 0.0019297036526533425,
#  'lorry': 0.0002756719503790489,
#  'driving': 0.007580978635423846,
#  'wrong': 0.018470020675396277,
#  'road': 0.01323225361819435,
#  'ploughed': 0.0008270158511371468,
#  'rental': 0.0011026878015161956,
#  'lot': 0.043694004135079255,
#  'pain': 0.002618883528600965,
#  'guessed': 0.0005513439007580978,
#  'toes': 0.00013783597518952445,
#  'broken': 0.010337698139214336,
#  'waterford': 0.0002756719503790489,
#  'man': 0.04079944865609924,
#  'thinking': 0.008407994486560993,
#  'maybe': 0.007856650585802894,
#  'cortisone': 0.00013783597518952445,
#  'injection': 0.0016540317022742937,
#  'know': 0.04962095106822881,
#  'felt': 0.014610613370089594,
#  'muscles': 0.0005513439007580978,
#  'ripped': 0.0006891798759476223,
#  'pelvis': 0.00013783597518952445,
#  'therapy': 0.0004135079255685734,
#  'ultra': 0.0011026878015161956,
#  'hopefully': 0.00647829083390765,
#  'd': 0.009235010337698139,
#  'knew': 0.009924190213645762,
#  'certainty': 0.0008270158511371468,
#  'places': 0.010062026188835286,
#  'vertebrae': 0.0002756719503790489,
#  'exploded': 0.0009648518263266712,
#  'fierce': 0.0033080634045485873,
#  'lucky': 0.002618883528600965,
#  ...}

# %% [markdown]
# ## **3.Calculating Sentence Scores**

# %%
def score_sentences(sents, freq_dist, max_len=40):
    sent_scores = {}  
    for sent in sents:
        words = sent.split(' ')
        for word in words:
            if word.lower() in freq_dist.keys():
                if len(words) < max_len:
                    if sent not in sent_scores.keys():
                        sent_scores[sent] = freq_dist[word.lower()]
                    else:
                        sent_scores[sent] += freq_dist[word.lower()]
    return sent_scores

sent_scores = score_sentences(sents, freq_dist)
sent_scores
# Out:
# {'Tate Lyle boss bags top award Tate Lyle chief executive has been named European Businessman of the Year by leading business magazine': 0.6745692625775327,
#  'Iain Ferguson was awarded the title by US publication Forbes for returning one of the UK venerable manufacturers to the country top companies': 0.34858718125430743,
#  'The sugar group had been absent from the FTSE for seven years until Mr Ferguson helped it return to growth': 0.7765678842177809,
#  'Tate shares have leapt this year boosted by firming sugar prices and sales of its artificial sweeteners': 0.47663680220537563,
#  'After years of sagging stock price and seven year hiatus from the FTSE one of Britain venerable manufacturers has returned to the vaunted index Forbes said': 1.6215024121295658,
#  'Mr Ferguson took the helm at the company in after spending most of his career at consumer goods giant Unilever': 0.6991040661612682,
#  'Tate Lyle which was an original member of the historic FT index in operates more than factories and more additional production facilities in countries': 0.13824948311509302,
#  'Previous winners of the Forbes award include Royal Bank of Scotland chief executive Fred Goodwin and former Vodafone boss Chris Gent': 0.35478980013783595,
#  'Halo sells five million copies Microsoft is celebrating bumper sales of its Xbox sci fi shooter Halo': 0.23818056512749836,
#  'The game has sold more than five million copies worldwide since it went on sale in mid November the company said': 1.4566505858028944,
#  'Halo has proved popular online with gamers notching up record million hours playing the game on Xbox Live': 0.4567884217780841,
#  'According to Microsoft nine out of Xbox Live members have played the game for an average of minutes per session': 0.3764300482425913,
#  'The sequel to the best selling Need for Speed Underground has inched ahead of the competition to take the top slot in the official UK games charts': 0.5699517574086836,
#  'The racing game moved up one spot to first place nudging GTA San Andreas down to second place': 0.3597518952446589,
#  'Halo dropped one place to five while Half Life fell to number nine': 0.31977946243969674,
#  'Last week new releases GoldenEye Rogue Agent and Killzone both failed to make it into the top debuting at number and respectively': 0.6293590627153687,
#  'Record numbers of Warcraft fans are settling in the games online world': 0.40675396278428666,
#  'On the opening day of the World of Warcraft massive multi player online game more than players signed up to play': 0.6474155754651965,
#  'On the evening of the first day more than players were in the world forcing Blizzard to add another servers to cope with the influx': 0.3372846312887663,
#  'David Yarnton Nintendo UK general manager told press conference to look out for details in the New Year': 1.096209510682288,
#  'Its US launch was on Sunday and it goes on sale in Japan on December': 0.17491385251550653,
#  'Nintendo has share of the handheld gaming market and said it expected to sell around five million of the DS by March': 1.3813921433494143,
#  'MSPs hear renewed climate warning Climate change could be completely out of control within several decades the Scottish Environment Protection Agency is warning committee of MSPs': 0.22053756030323915,
#  'Experts are giving evidence on the subject to the Scottish Parliament environment committee': 0.13907649896623017,
#  'Officials believe nuclear energy and wind farms may be better options than trying to tackle global warming': 0.20482425913163338,
#  'Solutions suggested by conservationists include reducing internal UK air travel and boosting electric trains': 0.24824259131633356,
#  'The evidence is part of the committee inquiry into the impact of climate change in Scotland': 0.1561681598897312,
#  'This dodgy government that brought us the dodgy dossier is now publishing dodgy Budget based on dodgy numbers he said': 1.29855272226051,
#  'You now propose to borrow over the next six years no less than billion so much for prudence': 0.1536871123363198,
#  'The chancellor forecasts of surpluses are no better than the prime minister forecasts of weapons of mass destruction': 0.24052377670572017,
#  'Mr Brown council tax rebate for pensioners was less than what the Tories were offering Mr Howard said': 2.085733976567884,
#  'There was nothing in the Budget that would put more police on the streets make hospitals cleaner or give parents and teachers the discipline and skills they wanted in schools': 0.28904203997243283,
#  'People would face clear choice at the election either more waste and higher taxes under Labour or lower taxes and value for money with the Conservatives he said': 1.7596140592694691,
#  'That the battleground of this election': 0.0917987594762233,
#  'That what this election is going to be all about and say bring it on he concluded to loud Tory cheering': 0.3197794624396967,
#  'Games win for Blu ray DVD format The next generation DVD format Blu ray is winning more supporters than its rival according to its backers': 0.8253618194348726,
#  'Blu ray backed by firms including Sony is competing against Toshiba and NEC backed HD DVD to be the format of choice for future films and games': 0.8636802205375603,
#  'The Blu Ray Association said on Thursday that games giants Electronic Arts and Vivendi would both support its DVD format': 2.4851826326671262,
#  'The next generation of DVDs will hold high definition video and sound': 0.41764300482425915,
#  'This offers incredible like quality of pictures which major Hollywood studios and games publishers are extremely keen to exploit in the coming year': 1.3772570640937283,
#  'In separate press conference at the Consumer Electronics Show in Las Vegas Toshiba announced that DVD players for its technology would be on the market by the end of': 0.963749138525155,
#  'As we move from standard definition video images to high definition images we have much greater need for storage Richard Doherty from Panasonic Hollywood Laboratories one of the pioneers of Blu ray told the BBC news website': 1.3491385251550656,
#  'So by utilising blue laser based technology we can make an optical laser disc that can hold six times as much as today DVD': 0.8159889731219848,
#  'A Blu ray disc will be able to store GB of high quality data while Toshiba HD DVD will hold GB': 0.5896623018607857,
#  'Mr Doherty added that it was making sure the discs could satisfy all high definition needs including the ability to record onto the DVDs and smaller discs to fit into camcorders': 1.7265334252239832,
#  'Both Toshiba and Blu ray are hopeful that the emerging DVD format war akin to the Betamax and VHS fight in the can be resolved over the next year when next generation DVD players start to come out': 1.326809097174363,
#  'When players do come out they will be able to play standard DVDs too which is good news for those who have huge libraries of current DVDs': 1.0494831150930393,
#  'But the support from Vivendi and Electronics Arts is big boost to Blu ray in the battle for supremacy': 0.349276361130255,
#  'Gaming is billion industry worldwide so is as crucial as the film industry in terms of money to be made': 0.7443142660234322,
#  'The technical requirement for game development today demands more advanced optical disc technologies said Michael Heilmann chief technology officer for Vivendi Universal': 2.827291523087525,
#  'Blu ray offers the capacity performance and high speed internet connectivity to take us into the future of gaming': 0.5783597518952447,
#  'EA leading games developer and publisher added that the delivery of high definition games of the future was vital and Blu ray had the capacity functionality and interactivity needed for the kinds of projects it was planning': 1.092487939352171,
#  'Sony recently announced it would be using the technology in its next generation of PlayStations': 0.45430737422467266,
#  'Mr Doherty said gamers were ravenous for high quality graphics and technology for the next generation of titles': 3.2827015851137147,
#  'Gamers especially those working on PCs are always focused on more capacity to deliver textures deeper levels for delivering higher resolution playback': 0.31922811853893873,
#  'He added The focus for games moving forward on increased immersion': 0.25747760165403166,
#  'Gaming companies really like to focus on creating world which involves creating complicated models and textures and increasing the resolution increasing the frame rate all of these are part of getting more immersive experience': 1.1616815988973122,
#  'Fitting these models on current DVD technologies means compressing the graphics so much that much of this quality is lost': 0.37050310130944175,
#  'As games move to more photo real capability the current technology is limiting': 0.5116471399035147,
#  'They are thrilled at the advanced capacity to start to build these immersive environments said Mr Doherty': 3.0056512749827706,
#  'Currently graphics intensive PC games also require multiple discs for installation': 0.338249483115093,
#  'High definition DVDs will cut down on that need': 0.3931082012405238,
#  'Likewise consoles rely on single discs so DVDs that can hold six times more data mean much better high resolution games': 0.805513439007581,
#  'Blu ray has already won backing from major Hollywood studios such as MGM Studios Disney and Buena Vista as well as top technology firms like Dell LG Samsung and Phillips amongst others': 0.9141281874569261,
#  'While Toshiba HD DVD technology has won backing from Paramount Universal and Warner Bros The real world benefits of HD DVD are apparent and obvious said Jim Cardwell president of Warner Home Video': 3.342522398345969,
#  'Mr Cardwell added that rapid time to market and dependability were significant factors in choosing to go with HD DVD': 1.6995175740868365,
#  'Both formats are courting Microsoft to be the format of choice for the next generation Xbox but discussions are still on going': 0.39283252929014467,
#  'Next generation DVDs will also be able to store images and other data': 0.28090971743625087,
#  'CES is the largest consumer electronics show in the world and runs from to January': 0.5659545141281875,
#  'Labour pig poster anti Semitic The Labour Party has been accused of anti Semitism over poster depicting Michael Howard and Oliver Letwin who are both Jewish as flying pigs': 0.5429359062715369,
#  'Prospective Tory candidate Andrew Mennear whose Finchley constituency contains large Jewish community branded it tasteless and offensive': 0.11867677463818056,
#  'The poster shows the two men faces superimposed on winged pigs and says the day the Tory sums add up': 0.28890420399724326,
#  'Labour said the poster was not anti Jewish but anti Tory': 1.2424534803583733,
#  'It is one of four designs mailed to Labour members who were asked to vote for their favourite': 0.21268090971743625,
#  'Mr Mennear who was sent the mail by friend said he had been shocked by the image and had shown it to friends who were similarly horrified': 1.51592005513439,
#  'He said there was nothing more distasteful for Jewish person than to be associated with pig': 1.028394210889042,
#  'am not suggesting there is any deliberate intent but these sort of things can cause great offence': 0.1177119228118539,
#  'It clearly wasn thought through': 0.05513439007580978,
#  'It is possible the posters were designed for maximum impact but this one clearly overstepped the mark and should be withdrawn': 0.11440385940730531,
#  'The campaign was particularly insensitive as it had come out at the same time as Holocaust Day difficult time for many Jewish people Mr Mennear added': 1.3862164024810475,
#  'A Labour spokesman denied the campaign was anti Semitic': 0.2697450034458994,
#  'As we said at the time the James report the Tory backed inquiry into possible public spending savings was published pigs will fly before the Tory sums will add up': 1.5448656099241902,
#  'This poster is making serious point he said': 1.0850447966919365,
#  'A Conservative Party spokesman said While the Conservatives are concentrating on the issues that matter to people such as lower taxes and controlled immigration it is clear to see that the Labour Party is not': 1.7880082701585116,
#  'People will not be fooled': 0.28242591316333565,
#  'Costin aims for comeback in Jamie Costin should be paralysed': 0.02563749138525155,
#  'He says so himself in matter of fact way as he recalls the car accident which occurred nine days before he was scheduled to step out into the Olympic Stadium in Athens for the Walk': 0.37560303239145415,
#  'There is an ironic chuckle as he talks of his immediate thoughts after lorry driving on the wrong side of the road had ploughed into his rental car': 0.09207443142660234,
#  'was in lot of pain and guessed that one of my toes was broken says the Waterford man': 0.19310820124052377,
#  'But was thinking maybe with cortisone injection you never know': 0.06767746381805652,
#  'In my back it felt as though all the muscles had been ripped off my pelvis but was thinking maybe we could do something with laser therapy and ultra sound and hopefully d be able to race': 0.13507925568573398,
#  'It took over hours before Jamie knew with certainty that he would not be competing in his second Olympics': 0.1910406616126809,
#  'My back had been broken in two places and with one of my vertebrae the bottom part had exploded so m fierce lucky not be paralysed': 0.1233631977946244,
#  'd fractured my big toe as well which was on the brake': 0.06850447966919367,
#  'Jamie didn finally arrive at hospital in Athens until some nine and half hours after the accident': 0.15203308063404547,
#  'For the first nine hours had no pain killers which was ridiculous in degrees heat': 0.02866988283942109,
#  'But once got the scans and saw them it was case of moving on and thinking OK ve got different set of circumstances now': 0.3791867677463818,
#  'Within three days he was arriving back in Ireland by air ambulance': 0.10268780151619573,
#  'Doctors in Athens had wanted to operate on Jamie back immediately but he insisted on delaying any surgery until he arrived back home something he is now very relieved about': 0.1848380427291523,
#  'The Greek doctors were going to put three or four inch titanium rods either side of my spinal cord up through my vertebrae': 0.10351481736733288,
#  'That would have fused all my lower back and would never have been able to race again': 0.08490696071674708,
#  'They were really putting lot of pressure on me to agree to the surgery': 0.14210889042039973,
#  'But when got to the Mater in Dublin they said it was possible for it to heal totally naturally which is giving me the chance to get back into competition which is very important to me': 1.2064782908339078,
#  'The people at the Mater have been absolutely fantastic': 0.29896623018607854,
#  'Jamie had to wear body cast for three and half months after the accident and spent most of that time flat on his back': 0.37505168849069603,
#  'He then progressed to crutches for six weeks until he was finally able to walk unaided on January': 0.13039283252929015,
#  'Walking without the crutches seemed like something finally really measurable in terms of my recovery': 0.21419710544452103,
#  'Physio sessions with Johnston McEvoy in Limerick have been vital part of his recovery': 0.027429359062715368,
#  'Johnston uses an advanced type of acupuncture and it very effective': 0.029496898690558236,
#  'Needles get put right close up to my spine': 0.08656099241902136,
#  'A two and half inch needle went in yesterday and m fairly incapacitated today as result': 0.2625775327360441,
#  'Jamie has also travelled to receive treatment at the Polish training centre in Spala where he has trained with triple Olympic champion Robert Korzeniowski over the past five years': 0.323776705720193,
#  'was there for over fortnight earlier this month and underwent fair extreme treatment called cryotherapy': 0.17574086836664368,
#  'Basically there a small room which is cooled by liquid nitrogen to minus degrees centigrade and it promotes deep healing': 0.05017229496898691,
#  'Jamie heads to Poland again on Sunday where he will be having daily cryotherapy in addition to twice daily physio sessions and pool work': 0.21557546519641627,
#  'All these sessions are small steps on the way to what Jamie hopes will be return to racing in': 0.20551343900758098,
#  'It all about trying to get mobility in my back': 0.02784286698828394,
#  'Lying down for three and half months didn really help with the strength': 0.2744314266023432,
#  'There a lot of work involved in my recovery': 0.16195727084769124,
#  'I doing about six hours day between physio and pool work': 0.19972432804962095,
#  'm also going to the gym to lift very light weights to try and build up my muscles': 0.25265334252239835,
#  'I fairly full on with everything do': 0.003170227429359063,
#  'd hope to be training regularly by March': 0.08725017229496898,
#  'But training is just part of the process of getting back': 0.19738111647139903,
#  'At the moment every time go and do big bit of movement my whole pelvic area all down my lower back just tightens up': 0.4490696071674707,
#  'It a case of waiting and seeing how it reacts': 0.05982081323225362,
#  'Hopefully after four or five months my back won tighten up as much': 0.1536871123363198,
#  'Almagro continues Spanish surge Unseeded Nicolas Almagro became the fifth Spaniard to reach the last eight at the Buenos Aires Open ousting eighth seed Mariano Zabaleta': 0.1319090282563749,
#  'He showed admirable resolve to win rain affected match': 0.17036526533425222,
#  'Compatriot and seventh seed Rafael Nadal also reached the last eight beating Italian Potito Starace': 0.06423156443831839,
#  'Nadal playing in the outdoor clay event for the first time hit some powerful forehands to oust Starace in match delayed over an hour by rain': 0.38580289455547895,
#  'It always problem to have to stop for rain but one gets used to it said Spanish teenager Nadal': 1.164300482425913,
#  'Luckily was able to keep my pace going throughout the match': 0.18180565127498277,
#  'He will now play Gaston Gaudio who beat unseeded Brazilian Flavio Saretta in the day late match': 0.24190213645761544,
#  'Public show for Reynolds portrait Sir Joshua Reynolds Portrait of Omai will get public airing following fears it would stay hidden because of an export wrangle': 0.26147484493452783,
#  'The Tate Gallery unsuccessfully tried to buy the picture from its anonymous owner after ban was issued preventing the painting from leaving the UK': 0.2594073053066851,
#  'The th Century painting has remained in storage but the owner has agreed to allow it to be part of an exhibition': 0.1200551343900758,
#  'The exhibition of Reynolds work will be shown at Tate Britain from May': 0.1717436250861475,
#  'Joshua Reynolds The Creation of Celebrity will feature prints caricatures and sculpture by the th Century artist who painted some of the most famous personalities of his day': 0.14817367332873882,
#  'Portrait of Omai fetched the second highest amount for British painting when it was sold at auction for in': 0.21612680909717438,
#  'It was bought by London dealer who sold it on to collector': 0.11467953135768437,
#  'The unnamed collector wanted to take it out of the country but was barred from doing so by the government because of its historical significance': 0.2977257064093728,
#  'In March the Tate managed to raise funding to buy the portrait but the owner refused to sell and it has been held in storage since': 0.17656788421778083,
#  'The portrait is of young man who was dubbed the noble savage when he arrived in London from Polynesia': 0.1454169538249483,
#  'He became darling of London society and was invited to all the best parties by people who were fascinated by such an exotic character': 0.5324603721571329,
#  'Sir Joshua painted him after his arrival in and it became the artist most famous work after it was first exhibited at the Royal Academy in': 0.14913852515506548,
#  'Sport betting rules in spotlight group of MPs and peers has called for tightening of regulations controlling betting on sport': 0.24452101998621642,
#  'The Parliamentary Group on Betting and Gaming held substantial inquiry into betting last year': 0.4792556857339766,
#  'It followed fears that massive increase in betting on sport such as that done using the internet and mobile phones has led to more cheating': 0.32598208132322537,
#  'The all party group recommended ways to protect punters and improve the integrity of sports betting': 0.21791867677463816,
#  'They include proposal for raising the maximum jail sentence for gambling cheats above the current two years': 0.2450723638869745,
#  'Lord Condon head of the International Cricket Council anti corruption unit who originally made the call for longer prison sentences said the two year penalty was derisory': 1.580013783597519,
#  'You could get bigger sentence for failing to pay your hotel bill criminally than you could for corruption in major sports': 0.12432804962095106,
#  'Symbolically higher penalty perhaps as the Bill passes through the two Houses might be appropriate': 0.04658855961405928,
#  'Yes absolutely': 0.014059269469331497,
#  'And would add that unfortunately we are not addressing the core problems so therefore we can never address it in its totality he said': 1.067815299793246,
#  'We are fighting it in its immediate context but we are not fighting it in its strategic long term context': 0.12322536181943487,
#  'It is the political disputes and we need to resolve them and also the issue of illiteracy and poverty': 0.14128187456926258,
#  'This combined are breeding grounds of extremism and terrorism': 0.019297036526533425,
#  'On Monday the Pakistani president met Prime Minister Tony Blair at Downing Street on his first official visit to London': 0.45086147484493455,
#  'He is due to visit the Pakistani community in Manchester on Tuesday afternoon': 0.16430048242591316,
#  'The Mirror newspaper said on Tuesday it had been handed sensitive dossier outling the details of Gen Musharraf visit to Britain': 1.1549276361130254,
#  'The paper said the document had been found in London street by member of the public': 1.1925568573397658,
#  'It said the dossier contained details about his movements and also confidential police radio channels call signs and codes': 1.125430737422467,
#  'Speaking in London on Monday Gen Musharraf said al Qaeda was on the run in Pakistan': 1.162922122674018,
#  'But standing next to Mr Blair he added that it was crucial to tackle the core of what creates terrorists what creates an extremist militant environment which then leads on to terrorism': 0.6682288077188145,
#  'That is the resolution of political disputes': 0.038318401102687805,
#  'Mr Blair said the two leaders had talked about Afghanistan the wider war on terror the situation in the Middle East and the ongoing dispute over Kashmir': 1.6165403170227428,
#  'We agreed that in Afghanistan there is some cause for optimism about the progress that has been made there said Mr Blair': 1.5501033769813921,
#  'In respect of Iraq we agreed that whatever the issues of the past the important thing now is to see the strategy through and ensure that Iraq is capable of becoming stable and democratic state': 0.3080634045485872,
#  'Kuznetsova failed drugs test US Open champion Svetlana Kuznetsova has tested positive for banned drug according to Belgian authorities': 0.2636802205375603,
#  'Belgian sports minister Claude Eerdekens said that the Russian world number five tested positive for the stimulant ephedrine on December': 1.450861474844934,
#  'Kuznetsova was playing in an exhibition event in Charleroi at the time': 0.2540317022742936,
#  'Eerdekens said There is problem': 1.0332184700206755,
#  'Ephedrine was discovered': 0.004548587181254307,
#  'She remains innocent until proved guilty': 0.04355616815988973,
#  'She can ask for it to be tested again': 0.019710544452101998,
#  'The situation remains unclear as the tournament was not commissioned by the World Anti Doping Agency Wada the International Tennis Federation ITF or the Women Tennis Accosiation WTA': 0.4037215713301171,
#  'The test was carried out by regional Belgian authorities and Kuznetsova has not yet been able to have B sample tested': 0.11467953135768437,
#  'Speaking at the Australian Open on Monday before Eerdekens identified her Kuznetsova said m not worried': 1.2272915230875259,
#  'I not using anything to push myself': 0.05403170227429359,
#  'have not been notified of any positive test and think it is unfair that it come out the way it did': 0.36540317022742935,
#  'Eerdekens said that confirmation of the findings was sent last Friday to the player address in Spain as well as to the Belgian prosecutors office and the Belgian and Russian tennis federations': 1.21750516884907,
#  'He conceded Kuznetsova might have taken medicine which contained the banned substance': 0.052239834596829765,
#  'We have simply stated fact he said': 1.046037215713301,
#  'It is for the federation concerned to impose the disciplinary measures after procedure that respects the defence': 0.06285320468642316,
#  'Either the ephedrine was taken to improve her performance or it is because she took some medicine legitimately to cure an infection': 0.13149552033080633,
#  'However Kuznetsova naming was condemned by Russian tennis chief Shamil Tarpishchev': 0.10406616126809097,
#  'First of all this Belgian sports minister has broken every ethical rule in the book by naming player without any proof of wrongdoing without any basic evidence Tarpishchev said': 1.2235699517574088,
#  'We all know the basic principle in doping cases': 0.08407994486560992,
#  'If there is positive sample then they should notify the International Tennis Federation ITF as well as the national federation within three days he said': 1.1793246037215712,
#  'This is not the case here': 0.04011026878015162,
#  'As of today we have not received any statement from the doping officials nor did the ITF': 0.18483804272915233,
#  'Today called the ITF headquarters and they told me they know nothing about it': 0.2614748449345279,
#  'If WADA the World Anti Doping Agency was behind the testing then we would also have known something by now': 0.2662991040661613,
#  'Otherwise all these looks to me as pure fiction and fabrication of the facts': 0.02122674017918677,
#  'LSE doubts boost bidders shares Shares in Deutsche Boerse have risen more than after shareholder fund voiced opposition to the firm planned takeover of the London Stock Exchange': 0.4013783597518953,
#  'TCI which claims to represent owners of of Deutsche Boerse DB shares has complained that the bn bn offer for the LSE is too high': 0.5082012405237767,
#  'Opposition from TCI has fuelled speculation that the proposed takeover could fail': 0.05968297725706409,
#  'Rival exchange operator Euronext has also said it may bid for the LSE': 1.0860096485182633,
#  'Euronext operates the Paris Amsterdam Brussels and Lisbon bourses while Deutsche Boerse runs the Frankfurt exchange': 0.08628532046864232,
#  'BBC News spoke to number of analysts on Monday morning about shareholder worries over Deutsche Boerse bid for LSE': 0.439421088904204,
#  'Although none were prepared to speak on the record most thought it was unlikely that TCI opposition would halt the deal Obviously we ll have to wait and see but don think it will make much difference': 0.5199172984148863,
#  'Deutsche Boerse appears very committed said one London based broker': 1.1636113025499655,
#  'He forecast the takeover bid would succeed and was more concerned to see improvements in the daily running of the LSE': 0.1279117849758787,
#  'In voicing its opposition to the planned takeover TCI said it would prefer to see Deutsche Boerse return m to shareholders': 1.213645761543763,
#  'The Deutsche Boerse was prepared to pay for the LSE exceeds the potential benefits of this acquisition said TCI': 1.1210199862164025,
#  'Another Deutsche Boerse shareholder on Monday also appeared to back TCI call': 0.07167470709855271,
#  'Another investor in Deutsche Boerse has supported the view that payout to shareholders would be preferable to Deutsche Boerse overpaying for the LSE Reuters news agency reported': 0.2238456237077877,
#  'We prefer sensible entrepreneurial solution at price that is not too high said Rolf Dress spokesman for Union Investment': 1.2274293590627154,
#  'If that cannot be achieved then we would wish for distribution of liquid assets to shareholders': 0.04217780840799449,
#  'The Financial Times also reported third Deutsche Boerse shareholder as opposed to the deal': 0.19807029634734669,
#  'It quoted spokesman for US based hedge fund Atticus Capital complaining that the planned takeover appeared to be motivated by empire building rather than the best interests of shareholders': 0.3590627153687112,
#  'TCI has called for Deutsche Boerse to hold an emergency general meeting to discuss the bid for LSE': 0.24410751206064785,
#  'Yet under German business law DB does not have to gain shareholder approval before making significant acquisition': 0.2465885596140593,
#  'Deutsche Boerse said TCI opposition would not change its bid approach': 1.1204686423156445,
#  'Deutsche Boerse is convinced that its contemplated cash acquisition of the London Stock Exchange is in the best interests of its shareholders and the company it said': 1.4180565127498277,
#  'DB shares were up to euros by GMT the highest gainer in Frankfurt': 0.08656099241902138,
#  'Nintendo first launched its GameBoy console in and has dominated the market ever since': 0.30627153687112335,
#  'But its lead can no longer be taken for granted': 0.17560303239145414,
#  'Sony will enter the market later this year with its PlayStation Portable while start up companies Gizmondo and Tapwave Zodiac are also offering hybrid devices': 1.3204686423156446,
#  'We believe the DS will appeal to all ages both genders and gamers of any skill said David Yarnton Nintendo Europe general manager said at the recent press launch for the handheld': 4.712060647829085,
#  'With its two screens wireless connectivity and backwards compatibility with the GameBoy Advance the DS certainly has number of unique selling points': 0.40606478290833914,
#  'It went on sale in the US in mid November priced and Nintendo says sales have exceeded expectations without giving detailed figures': 0.7255685733976567,
#  'Japan and Europe will have to wait until the first quarter of to get the device': 0.29414197105444523,
#  'With more than two million pre orders for the device in Japan Nintendo is confident it will keep its number one spot': 0.5990351481736734,
#  'But will the device prove to be as revolutionary as claimed': 0.0873880082701585,
#  'The game ships with demo of Metroid Hunters D action title which can be played alone or with group of friends using the machine wireless capabilities': 0.8074431426602341,
#  'It certainly looks impressive on the small machine and plays smoothly even with group of people': 0.8758097863542385,
#  'The game can be controlled by using the supplied stylus to aim': 0.365816678152998,
# ...
#  'But serious problems remain and the growing divide between haves and have nots is angering voters': 0.10130944176430048,
#  'One Iraqi woman told Ms Alexander about her frustration as she watched TV adverts for private hospitals soon after having failed to track down basic medicines from Baghdad pharmacies': 0.3895244658855962,
#  'Observes Mr Hadi The economy at present marks big divide the rich get richer the poor get poorer': 0.5819434872501723,
#  'An indication of this can be seen in the world of finance where in contrast with the daily plight of ordinary people private banks operate only one of which is run in accordance with Islamic banking principles': 0.6300482425913163,
#  'Hopes are high for the future of finance so foreign banks have been buying into the sector': 0.25210199862164023,
#  'National Bank of Kuwait has bought majority stake in Credit Bank of Iraq the Jordanian investment bank Export Finance Bank has bought of National Bank of Iraq': 0.5291523087525845,
#  'Foreign firms also hope to cash in on the reconstruction effort': 0.16774638180565127,
#  'Bechtel efforts to rebuild schools and restore power have attracted controversy as well as boosting its bottom line while Halliburton has enjoyed wealth of military contracts': 0.1474844934527912,
#  'But the involvement of foreign firms in the health and banking sectors and beyond sits uneasily with many Iraqis who are accustomed to the state taking responsibility for functions that are essential to making society work observes Ms Alexander': 0.4333563059958649,
#  'It is seen as selling off of Iraq assets and bringing in multinationals at the expense of Iraqi businesses and Iraqi workers she says': 0.23997243280496208,
#  'Consequently the transitional government has been forced to backtrack in recent months over its proposal to allow foreign ownership of Iraqi assets she explains': 0.3835975189524466,
#  'In the West it is easy to forget that the otherwise brutal Baathist regime used to look after the majority of Iraq citizens rather well in terms of job creation social security and healthcare': 0.3236388697450034,
#  'Opinion polls suggest that people still want the state to take leading role in providing these things Ms Alexander says': 0.6605099931082012,
#  'Yet in some areas of the economy investment from abroad is still warmly welcomed insists Mr Hadi an Iraqi who left the country three decades ago': 0.695106822880772,
#  'think the private sector will evolve incredibly fast Mr Hadi says': 0.6461750516884907,
#  'Iraq vast natural resources can support any magnitude of economic growth': 0.20427291523087526,
#  'Many foreign companies say they are keen to get in on the act yet few are actually entering the country in any meaningful way': 0.4188835286009649,
#  'But Jaynes lawyer David Oblon called the nine year recommended term outrageous and said his client believed he was innocent': 2.9472088215024117,
#  'He pointed out that all three of the accused lived in North Carolina and were unaware of the Virginia state law': 0.29827705031013096,
#  'Spam messages are estimated to account for at least of all mails sent': 0.17835975189524464,
#  'Brainwave cap controls computer team of US researchers has shown that controlling devices with the brain is step closer': 0.3853893866299104,
#  'Four people two of them partly paralysed wheelchair users successfully moved computer cursor while wearing cap with electrodes': 0.8493452791178495,
#  'Previous research has shown that monkeys can control computer with electrodes implanted into their brain': 0.34183321847002063,
#  'The New York team reported their findings in the Proceedings of the National Academy of Sciences': 0.8788421778084081,
#  'The results show that people can learn to use scalp recorded electroencephalogram rhythms to control rapid and accurate movement of cursor in two directions said Jonathan Wolpaw and Dennis McFarlane': 2.9232253618194353,
#  'The research team from New York State Department of Health and State University of New York in Albany said the research was another step towards people controlling wheelchairs or other electronic devices by thought': 4.515506547208823,
#  'The four people faced large video screen wearing special cap which meant no surgery or implantation was needed': 0.9177119228118539,
#  'Brain activity produces electrical signals that can be read by electrodes': 0.06257753273604412,
#  'Complex algorithms then translate those signals into instructions to direct the computer': 0.14059269469331495,
#  'Such brain activity does not require the use of any nerves of muscles so people with stroke or spinal cord injuries could use the cap effectively': 1.054445210199862,
#  'The impressive non invasive multidimensional control achieved in the present study suggests that non invasive brain control interface could support clinically useful operation of robotic arm motorised wheelchair or neuroprosthesis said the researchers': 2.4771881461061334,
#  'The four volunteers also showed that they could get better at controlling the cursor the more times they tried': 0.2649207443142661,
#  'Although the two partially paralysed people performed better overall the researchers said this could be because their brains were more used to adapting or that they were simply more motivated': 2.9152308752584424,
#  'It is not the first time researchers have had this sort of success in brain control experiments': 0.53618194348725,
#  'Some teams have used eye motion and other recording techniques': 0.2004135079255686,
#  'Earlier this year team at the MIT Media Labs Europe demonstrated wireless cap which read brain waves to control computer character': 1.3066850447966918,
#  'Gronkjaer agrees switch to Madrid Jesper Gronkjaer has agreed move to Atletico Madrid from Birmingham City': 0.09951757408683667,
#  'The year old winger spent just five months at St Andrews following m move from Chelsea in July after playing for Denmark at Euro': 0.8453480358373535,
#  'He is set to move during the January transfer window in deal rumoured to be about subject to medical': 0.2372157133011716,
#  'We will meet with the player representative to finalise the contract and decide when he will sign said Atletico sporting director Toni Munoz': 1.1721571330117162,
#  'Gronkjaer has been targeted by Blues fans and was sarcastically applauded when taken off against Everton last month': 0.1386629910406616,
#  'Boss Steve Bruce had said that he would be happy to let the Danish international go if the price was right': 1.2278428669882837,
#  'He added m not going to say the decision to let him go is down to the fans reaction towards him': 0.4679531357684355,
#  'He has had tough time since the summer with the loss of his mother and finding it difficult to adjust to new club and different area': 0.6537560303239146,
#  'He has been terrific and not missed day training and is someone if your daughter brought them home you would be delighted': 0.2151619572708477,
#  'It just hasn quite worked out here for him': 0.17325982081323224,
#  'But we like to get back most of what we spent': 0.1386629910406616,
#  'Sony PSP handheld console hits US The latest handheld gaming gadget Sony PlayStation Portable goes on sale in the US on Thursday': 0.26285320468642315,
#  'The entertainment device which also stores images music and video is intended to compete with Nintendo DS released earlier this month in the UK': 0.5437629221226741,
#  'Gamers have been queuing outside shops across the US to get their hands on the gadget which costs about': 0.09290144727773948,
#  'The first million sold will come with the Spider Man film on UMD Sony own disc format for the device': 0.3994486560992418,
#  'The PSP can be linked up with others for multiplayer gaming via wireless connection': 0.06409372846312887,
#  'Sony has touted the machine as the Walkman of the st Century and has sold more than units in Japan since its launch there last year': 0.46629910406616126,
#  'But it faces stiff competition from the Nintendo DS which sold more than the GameCube in its first few days on release in Europe': 0.21157822191592002,
#  'It too allows for multiplayer gaming over the air': 0.04769124741557547,
#  'Nintendo dominates the handheld market with more than share of the market in the US alone': 0.2479669193659545,
#  'The Gizmondo combined media player phone and gaming gadget also went on sale in the UK last week': 0.4923501033769814,
#  'It hopes to take share of the handheld gaming market too': 0.1804272915230875,
#  'The story of the PSP is it not gaming device as much as it is portable entertainment device said Michael Pachter analyst at Wedbush Morgan Securities': 1.1833218470020674,
#  'He told the Reuters news agency that he expected Sony to sell about million PSPs in enough time to rival Apple iPod': 0.655961405926947,
#  'There is no date for the PSP release in Europe yet': 0.10640937284631288,
#  'Sony has promised to have million units ready for its US launch but there are fears demand may not be met': 0.21378359751895246,
#  'It also said it expected to ship three million PSPs worldwide by the end of its fiscal year ending March': 1.5949000689179873,
#  'The machine European launch was put back few months last week in order to make sure enough of the devices were ready for its US launch as well as satisfying the Japanese market': 0.5969676085458304,
#  'The PSP has almost as much processing power in it as the PlayStation console': 0.06299104066161268,
#  'Hundreds of gamers gathered at US shops some waiting for more than hours to be the first to get their hands on the gadget': 0.08793935217091661,
#  'A spokesman for one US shop said it expected the device to sell out on its first day': 1.2212267401791868,
#  'The games for the mini console include Ape Academy Formula One Wipeout Pure and Fired Up': 0.16209510682288075,
#  'Movie studios including Lions Gate Entertainment and Disney have also announced forthcoming film titles that will be made available on the UMD format': 0.34017918676774633,
#  'India opens skies to competition India will allow domestic commercial airlines to fly long haul international routes move it hopes will stoke competition and drive down prices': 0.3902136457615437,
#  'However only state controlled carriers will be able to fly the lucrative Gulf routes to countries such as Kuwait and Saudi Arabia for at least three years': 0.30310130944176433,
#  'Jet Airways and Air Sahara are the two companies that will benefit initially': 0.10268780151619573,
#  'India is looking to develop its airline industry as booming economic growth drives demand for travel': 0.3142660234321158,
#  'Monica Chadha BBC Delhi reporter said air travel in India had increased by almost from the previous year and was expected to rise even further': 1.639696760854583,
#  'Infrastructure development is lagging demand however and will have to improve': 0.07498277050310131,
#  'Most international airports in the country are shabby and ill equipped to handle heavy air traffic Ms Chada said adding that while the Civil Aviation minister has promised to modernise and privatise airports little progress has been made': 1.3860785665058581,
#  'Steps have been take to move things forward and the government recently changed legislation that limited foreign investment in domestic airlines': 0.3775327360441075,
#  'It raised the maximum stake holding allowed to from': 0.0518263266712612,
#  'Local press meanwhile have reported that the US and India will start negotiations about adding more routes in January': 0.22315644383184013,
#  'Jet Airways is India premier private domestic carrier Air Sahara is ranked third in the category': 0.11123363197794625,
#  'Mobile games come of age The BBC News website takes look at how games on mobile phones are maturing': 1.4227429359062718,
#  ...}

# %% [markdown]
# ## **4.Getting the Summary**

# %%
def summarize(sent_scores, k):
    top_sents = Counter(sent_scores) 
    summary = ''
    scores = []
    
    top = top_sents.most_common(k)
    for t in top: 
        summary += t[0].strip()+'. '
        scores.append((t[1], t[0]))
    return summary[:-1], scores

# %%
summary, summary_sent_scores = summarize(sent_scores, 3)
print(summary)
# Out:
# he said. For government that lectures everyone on choice choice on public service choice on this and choice on that isn it ironic that they re saying to public sector workers there is no choice he said. These rumours were fuelled by Mr Blair decision to hold his monthly media conference at the same time as long planned speech by Mr Brown on UK plans to tackle global poverty with new Marshall Plan for Africa.

# %% [markdown]
# # **Task4:Define the emotional tone**

# %%
X4 = X
y4 = y

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords

from numpy import array
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten
from keras.layers import GlobalMaxPooling1D
from keras.layers.embeddings import Embedding
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
# Out:
# Using TensorFlow backend.

# %%
sentences_list[:2]
# Out:
# ["Tate & Lyle boss bags top award\n\nTate & Lyle's chief executive has been named European Businessman of the Year by a leading business magazine.",
#  'Iain Ferguson was awarded the title by US publication Forbes for returning one of the UK\'s "venerable" manufacturers to the country\'s top 100 companies.']

# %% [markdown]
# ## **Preprocessing**

# %%
sentences = []

for sen in sentences_list:
    sentences.append(preprocess_text(sen))

# %%
sentences[:2]
# Out:
# ['Tate Lyle boss bags top award Tate Lyle chief executive has been named European Businessman of the Year by leading business magazine ',
#  'Iain Ferguson was awarded the title by US publication Forbes for returning one of the UK venerable manufacturers to the country top companies ']

# %% [markdown]
# ## **making target Y**

# %%
from textblob import TextBlob

# compute sentiment scores (polarity) and labels
sentiment_scores_tb = [round(TextBlob(article).sentiment.polarity, 3) for article in sentences]
sentiment_category_tb = ['positive' if score > 0  else 'negative' if score < 0  else 'neutral'  for score in sentiment_scores_tb]

# %%
# sentiment statistics per news category
df = pd.DataFrame([sentences, sentiment_scores_tb, sentiment_category_tb]).T
df.columns = ['news_category', 'sentiment_score', 'sentiment_category']
df['sentiment_score'] = df.sentiment_score.astype('float')

# %%
df.groupby(by=['news_category']).describe()
# Out:
#                                                    sentiment_score  ...
#                                                              count  ...    max
# news_category                                                       ...
#                                                                6.0  ...  0.000
#  AMR results for the fourth quarter of reflect ...             1.0  ...  0.028
#  Above all it will provide support to emerging ...             1.0  ...  0.000
#  Acceptance of new technologies always has tipp...             2.0  ...  0.136
#  Access to specialised film is currently restri...             1.0  ...  0.000
# ...                                                            ...  ...    ...
# with playwright Catherine Johnson and members o...             1.0  ...  0.375
# won the honour for pre school animation and its...             1.0  ...  0.375
# won the men event with season best of taking th...             1.0  ...  1.000
# won the men pole vault competition with clearan...             1.0  ...  0.333
# won the triple jump with leap of with Britain T...             1.0  ...  0.000
#
# [37840 rows x 8 columns]

# %%
'''fc = sns.factorplot(x="news_category", hue="sentiment_category", 
                    data=df, kind="count", 
                    palette={"negative": "#FE2020", 
                             "positive": "#BADD07", 
                             "neutral": "#68BFF5"})'''
# Out:
# 'fc = sns.factorplot(x="news_category", hue="sentiment_category", \n                    data=df, kind="count", \n                    palette={"negative": "#FE2020", \n                             "positive": "#BADD07", \n                             "neutral": "#68BFF5"})'

# %%
'''import model_evaluation_utils as meu
meu.display_confusion_matrix_pretty(true_labels=sentiment_category, 
                                    predicted_labels=sentiment_category_tb, 
                                    classes=['negative', 'neutral', 'positive'])'''
# Out:
# "import model_evaluation_utils as meu\nmeu.display_confusion_matrix_pretty(true_labels=sentiment_category, \n                                    predicted_labels=sentiment_category_tb, \n                                    classes=['negative', 'neutral', 'positive'])"

# %%
df.sentiment_category[0]
# Out:
# 'positive'

# %%
X = df.news_category.tolist()

# %%
X[:2]
# Out:
# ['Tate Lyle boss bags top award Tate Lyle chief executive has been named European Businessman of the Year by leading business magazine ',
#  'Iain Ferguson was awarded the title by US publication Forbes for returning one of the UK venerable manufacturers to the country top companies ']

# %% [markdown]
# ## Encoding Y

# %%
def f(x):
  if x =="positive":
    return 1
  elif x =="negative":
    return -1
  else:
    return 0

# %%
y = df['sentiment_category']

y = np.array(list(map(f, y)))

# %%
print(y)
# Out:
# [ 1  1  0 ...  1  1 -1]

# %% [markdown]
# ## Train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# ## **Preparing the embedding layer**

# %%
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(X_train)

X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a5bedcda2e17> in <module>()
# ----> 1 tokenizer = Tokenizer(num_words=5000)
#       2 tokenizer.fit_on_texts(X_train)
#       3
#       4 X_train = tokenizer.texts_to_sequences(X_train)
#       5 X_test = tokenizer.texts_to_sequences(X_test)
#
# NameError: name 'Tokenizer' is not defined

# %%
# Adding 1 because of reserved 0 index
vocab_size = len(tokenizer.word_index) + 1

maxlen = 100

X_train = pad_sequences(X_train, padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test, padding='post', maxlen=maxlen)

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# Out:
# --2020-01-16 11:19:37--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2020-01-16 11:19:37--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2020-01-16 11:19:37--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  2.02MB/s    in 6m 29s
#
# 2020-01-16 11:26:06 (2.12 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]

# %%
# !unzip glove*.zip
# Out:
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt

# %%
from numpy import array
from numpy import asarray
from numpy import zeros

embeddings_dictionary = dict()
glove_file = open('/content/glove.6B.100d.txt', encoding="utf8")

for line in glove_file:
    records = line.split()
    word = records[0]
    vector_dimensions = asarray(records[1:], dtype='float32')
    embeddings_dictionary [word] = vector_dimensions
glove_file.close()

# %%
embedding_matrix = zeros((vocab_size, 100))
for word, index in tokenizer.word_index.items():
    embedding_vector = embeddings_dictionary.get(word)
    if embedding_vector is not None:
        embedding_matrix[index] = embedding_vector

# %%
from keras.layers import Flatten , LSTM
model = Sequential()
embedding_layer = Embedding(vocab_size, 100, weights=[embedding_matrix], input_length=maxlen , trainable=False)
model.add(embedding_layer)
model.add(LSTM(128))

model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 100, 100)          2578500
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               117248
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,695,877
# Trainable params: 117,377
# Non-trainable params: 2,578,500
# _________________________________________________________________
# None

# %%
history = model.fit(X_train, y_train, batch_size=128, epochs=6, verbose=1, validation_split=0.2)

score = model.evaluate(X_test, y_test, verbose=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 26508 samples, validate on 6628 samples
# Epoch 1/6
# 26508/26508 [==============================] - 64s 2ms/step - loss: 0.5712 - acc: 0.3449 - val_loss: 0.5931 - val_acc: 0.3310
# Epoch 2/6
# 26508/26508 [==============================] - 64s 2ms/step - loss: 0.5623 - acc: 0.3437 - val_loss: 0.5994 - val_acc: 0.3310
# Epoch 3/6
# 26508/26508 [==============================] - 63s 2ms/step - loss: 0.5341 - acc: 0.3636 - val_loss: 0.4802 - val_acc: 0.4250
# Epoch 4/6
# 26508/26508 [==============================] - 63s 2ms/step - loss: 0.4622 - acc: 0.4146 - val_loss: 0.5806 - val_acc: 0.4012
# Epoch 5/6
# 26508/26508 [==============================] - 63s 2ms/step - loss: 0.3586 - acc: 0.4649 - val_loss: 0.5638 - val_acc: 0.4392
# Epoch 6/6
# 26508/26508 [==============================] - 64s 2ms/step - loss: 0.2379 - acc: 0.4813 - val_loss: 0.4495 - val_acc: 0.5732
# 8284/8284 [==============================] - 7s 895us/step

# %%
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
# Out:
# Test Score: 0.4574852267191181
# Test Accuracy: 0.5689280540513739

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])

plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')

# %% [markdown]
# ## **Prediction**

# %%
instance = X[57]
print(instance)
# Out:
# The Tory leader who argues he is ensuring honesty said We do not say one thing in private and another thing in public

# %%
instance = tokenizer.texts_to_sequences(instance)

flat_list = []
for sublist in instance:
    for item in sublist:
        flat_list.append(item)

flat_list = [flat_list]

instance = pad_sequences(flat_list, padding='post', maxlen=maxlen)

model.predict(instance)
# Out:
# array([[0.7252859]], dtype=float32)

# %% [markdown]
# ## **Method2 :**

# %%
import	pandas as pd
df =pd.read_csv('/content/drive/My Drive/data.csv')

# %%
df.head()
# Out:
#                    Id  ...                                              Tweet
# 0  635769805279248384  ...                                      Not Available
# 1  635930169241374720  ...  IOS 9 App Transport Security. Mm need to check...
# 2  635950258682523648  ...  Mar if you have an iOS device, you should down...
# 3  636030803433009153  ...  @jimmie_vanagon my phone does not run on lates...
# 4  636100906224848896  ...  Not sure how to start your publication on iOS?...
#
# [5 rows x 3 columns]

# %%
df.shape
# Out:
# (5970, 3)

# %%
import seaborn as sns

sns.countplot(x='Category', data=df)

# %%
# remove the tweets which contains Not available

df = df[df['Tweet'] != "Not Available"]

# %%
def clean_tweets(tweet):
    
    # remove URL
    tweet = re.sub(r"http\S+", "", tweet)
    
    # Remove usernames
    tweet = re.sub(r"@[^\s]+[\s]?",'',tweet)
    
    # remove special characters 
    tweet = re.sub('[^ a-zA-Z0-9]', '', tweet)
    
    # remove Numbers
    tweet = re.sub('[0-9]', '', tweet)
    
    return tweet

# %%
# Apply function to Tweet column

df['Tweet'] = df['Tweet'].apply(clean_tweets)

# %%
df['Tweet'].head()
# Out:
# 1    IOS  App Transport Security Mm need to check i...
# 2    Mar if you have an iOS device you should downl...
# 3    my phone does not run on latest IOS which may ...
# 4    Not sure how to start your publication on iOS ...
# 5    Two Dollar Tuesday is here with Forklift  Quic...
# Name: Tweet, dtype: object

# %%
X = []
sentences = list(df['Tweet'])
for sen in sentences:
    X.append(sen)

# %%
X[0]
# Out:
# 'IOS  App Transport Security Mm need to check if my rd party network pod supports it '

# %%
y = df['Category']


y = np.array(list(map(f, y)))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X1_train = X_train

# %%
X1_test = X_test

# %%
y1_test = y_test

# %%
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(X_train)

X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
# Adding 1 because of reserved 0 index
vocab_size = len(tokenizer.word_index) + 1

maxlen = 100

X_train = pad_sequences(X_train, padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test, padding='post', maxlen=maxlen)

# %%
from numpy import array
from numpy import asarray
from numpy import zeros

embeddings_dictionary = dict()
glove_file = open('/content/glove.6B.100d.txt', encoding="utf8")

for line in glove_file:
    records = line.split()
    word = records[0]
    vector_dimensions = asarray(records[1:], dtype='float32')
    embeddings_dictionary [word] = vector_dimensions
glove_file.close()

# %%
embedding_matrix = zeros((vocab_size, 100))
for word, index in tokenizer.word_index.items():
    embedding_vector = embeddings_dictionary.get(word)
    if embedding_vector is not None:
        embedding_matrix[index] = embedding_vector

# %%
from keras.layers import Conv1D
model = Sequential()

embedding_layer = Embedding(vocab_size, 100, weights=[embedding_matrix], input_length=maxlen , trainable=False)
model.add(embedding_layer)

model.add(Conv1D(128, 5, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 100, 100)          1011200
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 96, 128)           64128
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,075,457
# Trainable params: 64,257
# Non-trainable params: 1,011,200
# _________________________________________________________________
# None

# %%
history = model.fit(X_train, y_train, batch_size=128, epochs=6, verbose=1, validation_split=0.2)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 3469 samples, validate on 868 samples
# Epoch 1/6
# 3469/3469 [==============================] - 3s 879us/step - loss: 0.5671 - acc: 0.4249 - val_loss: 0.3789 - val_acc: 0.4862
# Epoch 2/6
# 3469/3469 [==============================] - 3s 743us/step - loss: 0.3552 - acc: 0.4837 - val_loss: 0.2981 - val_acc: 0.5127
# Epoch 3/6
# 3469/3469 [==============================] - 3s 754us/step - loss: 0.1981 - acc: 0.5417 - val_loss: 0.1827 - val_acc: 0.5058
# Epoch 4/6
# 3469/3469 [==============================] - 3s 763us/step - loss: 0.0764 - acc: 0.5515 - val_loss: 0.1232 - val_acc: 0.5276
# Epoch 5/6
# 3469/3469 [==============================] - 3s 749us/step - loss: -0.0471 - acc: 0.5788 - val_loss: 0.0297 - val_acc: 0.5115
# Epoch 6/6
# 3469/3469 [==============================] - 3s 744us/step - loss: -0.1931 - acc: 0.5892 - val_loss: -0.0158 - val_acc: 0.5392

# %%
score = model.evaluate(X_test, y_test, verbose=1)
# Out:
# 1085/1085 [==============================] - 0s 294us/step

# %%
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
# Out:
# Test Score: 0.10122355607248122
# Test Accuracy: 0.5391705067476369

# %%
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([[0.7248949 ],
#        [0.75760245],
#        [0.01602125],
#        ...,
#        [0.00176515],
#        [0.2066353 ],
#        [0.05185306]], dtype=float32)

# %%
X1_train[0]
# Out:
# 'ICYMI Heres what you must know about Texas decision to defund cancer screenings  Planned Parenthood on Sept   '

# %%
y1_test[0]
# Out:
# 0

# %%
y_pred[0]
# Out:
# array([0.7248949], dtype=float32)

# %%
CATEGORIES ={1 : 'positive' , -1 : 'negative' , 0 : 'neutre'}

# %%
pred_name = CATEGORIES[np.argmax(y_pred[0][0])]
print(pred_name)
# Out:
# neutre
